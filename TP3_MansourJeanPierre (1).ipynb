# %% [markdown]
# Dans ce TP nous allons voir une famille particulière de réseaux de neurones: les auto-encoders

# %% [markdown]
# ## Auto-encoders

# %% [markdown]
# Pour ce premier exemple sur les auto-encodeurs nous utiliserons le jeu de donnée MNIST.
# Comme pour le TP précédent, nous allons normaliser les données d'entrées et rajouter une dimension représentant les channels car les images sont en noir et blanc.

# %%
import numpy as np
from keras.datasets import mnist
((x_train, y_train), (x_test, y_test)) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
print(f'x_train shape before adding the "channels" dimension:{x_train.shape}')
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
print(f'x_train shape after adding the "channels" dimension:{x_train.shape}')
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train shape before adding the "channels" dimension:(60000, 28, 28)
# x_train shape after adding the "channels" dimension:(60000, 28, 28, 1)

# %% [markdown]
# Les auto-encodeurs sont des réseaux de neurones utilisés le plus souvent pour apprendre de façon non-supervisée ou faiblement supervisée une représentation (features/encodages) d'un jeu de données.
# Les auto-encodeurs sont généralement constitués de deux éléments:
# * Un encodeur, chargé de réprésenter les données dans un espace le plus souvent de dimension réduite
# * Un décodeur, capable à partir d'une donnée encodée de reconstruire la donnée initiale
# ![Source wikipedia](https://upload.wikimedia.org/wikipedia/commons/2/28/Autoencoder_structure.png)
#
#
# Le code suivant instancie un décodeur.
# Nous avions l'habitude de construire des réseaux de neurones à l'aide de la classe ```Sequential``` de Keras.  Nous allons cette fois-ci utiliser la methode fonctionnelle en important la clase ```Model``` de Keras.
# Cette méthode offre un peu plus de souplesse que sequentielle. Elle permet notamment de définir un modèle comme une composition de fonctions/couches.
# Définissons le modèle de notre encodeur de cette manière.

# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

# On commence par définir une couche d'entrées
input_img = Input(shape=(28, 28, 1))
# On definit ensuite les couches suivantes à la manière d'un graph: couche = TypeDeCouche(paramètres_de_la_couche)(CouchePrécédente)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# On définit alors le model à partir de sa couche d'entrée et sa couche de sortie
encoder = Model(input_img, encoded)

# %% [markdown]
# L'encodeur reçoit donc en entrée une image de taille ```28*28```. A partir de cette image il va produire une representation de plus petite dimension.
# Cette representation est ce que l'on appelle les **features**.
# Regardons la dimension de la sortie de notre encodeur:

# %%
print(encoder.predict(x_train[:1]).shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# (1, 4, 4, 8)

# %% [markdown]
# En vous inspirant du code utilisé pour définir l'encodeur, vous allez maintenant coder vous même le décodeur en utilisant l'API Model de Keras.
# Nous utiliserons une nouvelle couche proposée dans l'API de Keras, la couche [UpSampling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D) permettant d'augmenter la taille d'un tenseur en répétant ses lignes et ses colonnes.
# Le décodeur sera composé des couches suivantes:
# * Une couche d'inputs faite pour recevoir des tenseurs de la dimension des encodages générés par l'encodeur
# * Une couche Conv2D 8 filtres, kernel (3,3) activation ReLU et padding=same
# * Une couche UpSampling2D((2,2))
# * Une couche Conv2D 8 filtres, kernel (3,3) activation ReLU et padding=same
# * Une couche UpSampling2D((2,2))
# * Une couche Conv2D 16 filtres, kernel (3,3) activation ReLU
# * Une couche UpSampling2D((2,2))
# * Une couche Conv2D 1 filtre, kernel (3,3) activation Sigmoid et padding=same
#
# La couche de sigmoïde permettra d'obtenir des sorties comprises entre 0 et 1.

# %%
from tensorflow.keras.layers import UpSampling2D

input_dec = Input(shape=(4, 4, 8))

x = Conv2D(8, (3, 3), activation='relu', padding='same')(input_dec)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

decoder = Model(input_dec, decoded)

# %% [markdown]
# Vérifiez que la sortie de votre décodeur est bien de la forme ```(batch_size, 28, 28, 1)```

# %%
batch_size = 16
y = encoder.predict(x_train[:batch_size])
decoder.predict(y).shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# (16, 28, 28, 1)

# %% [markdown]
# Nous pouvons maintenant créer un seul modèle à partir des deux précédents toujours en utilisant Model de Keras

# %%
auto_encoder = Model(inputs=encoder.input, outputs=decoder(encoder.output))

# %% [markdown]
# Vérifiez que les deux modèles sont bien reliés.
# Vous devez obtenir une image ne contenant que du bruit.
# C'est normal car nous n'avons pas encore entrainé nôtre auto-encodeur.

# %%
import matplotlib.pyplot as plt

plt.imshow(auto_encoder.predict(x_train[:1]).reshape(28, 28), cmap="gray")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step

# %% [markdown]
# Entrainons maintenant le modèle entier.
# Sagissant d'une tache de reconstruction celà revient à prédire la valeur prise par chaque pixel de notre image de sortie.
# Les images étant des pixels prennant la valeur 1 ou 0, nous utiliserons donc la binary_crossentropy de Keras qui sera appliquée sur chacun des pixels.

# %%
auto_encoder.compile(optimizer='adam', loss='binary_crossentropy')
auto_encoder.fit(x_train, x_train, epochs=25, batch_size=128, shuffle=True, validation_data=(x_test, x_test))
# Out:
# Epoch 1/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 0.3169 - val_loss: 0.1513
# Epoch 2/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1457 - val_loss: 0.1315
# Epoch 3/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1304 - val_loss: 0.1236
# Epoch 4/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1236 - val_loss: 0.1183
# Epoch 5/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1184 - val_loss: 0.1143
# Epoch 6/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1149 - val_loss: 0.1114
# Epoch 7/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1123 - val_loss: 0.1095
# Epoch 8/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1102 - val_loss: 0.1073
# Epoch 9/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1081 - val_loss: 0.1059
# Epoch 10/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1070 - val_loss: 0.1049
# Epoch 11/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1054 - val_loss: 0.1035
# Epoch 12/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1046 - val_loss: 0.1026
# Epoch 13/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1037 - val_loss: 0.1020
# Epoch 14/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1028 - val_loss: 0.1012
# Epoch 15/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1022 - val_loss: 0.1010
# Epoch 16/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1014 - val_loss: 0.1002
# Epoch 17/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1010 - val_loss: 0.0995
# Epoch 18/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1006 - val_loss: 0.0990
# Epoch 19/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1002 - val_loss: 0.0985
# Epoch 20/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0994 - val_loss: 0.0981
# Epoch 21/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0992 - val_loss: 0.0977
# Epoch 22/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0990 - val_loss: 0.0974
# Epoch 23/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0983 - val_loss: 0.0977
# Epoch 24/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0980 - val_loss: 0.0976
# Epoch 25/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0978 - val_loss: 0.0964

# %% [markdown]
# Nous avons entrainé le modèle auto-encoder, composé lui même de deux sous-modèles.
# L'encodeur encode donc les images dans des tenseurs de dimension ```(batch_size,4,4,8)```.
# A partir de ces encodages le décodeur est capable de reconstituer l'image de départ.

# %%
z_test = encoder.predict(x_test)
y_pred = decoder.predict(z_test)
print(f'encodages z_test: {z_test.shape}')
print(f'prédictions y_pred: {y_pred.shape}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# encodages z_test: (10000, 4, 4, 8)
# prédictions y_pred: (10000, 28, 28, 1)

# %% [markdown]
# Le code suivant nous permet de visualiser le résultat de notre apprentissage sur quelques exemples:

# %%
plt.figure(figsize=(20, 4))
for i in range(10):
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('Original')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, 10, i + 11)
    plt.imshow(y_pred[i].reshape(28, 28), cmap='gray')
    plt.title('Reconstruction')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Denoising auto-encoder
# Nous allons maintenant utiliser des auto-encodeurs pour débruiter des images.
# Commençons pour cela par générer des images bruitées.
# Utilisez la fonction [random.normal](https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.normal.html) de numpy pour rajouter un bruit gaussien sur une copie de x_train et de x_test. Utilisez un bruit centré avec un ecart type de 0.5.
# Afin que les images bruitées soient toujours comprises entre 0 et 1 utilisez la fonction [clip](https://docs.scipy.org/doc/numpy/reference/generated/numpy.clip.html) de numpy toujours pour caper les données bruitées que vous venez de générer.

# %%
x_train_noisy = x_train + np.random.normal(loc=0.0, scale=0.5, size=x_train.shape)
x_test_noisy = x_test + np.random.normal(loc=0.0, scale=0.5, size=x_test.shape)
# n'oubliez pas de clipper les valeurs obtenues
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# Verifiez vos images perturbées en en affichant quelques unes

# %%
plt.figure(figsize=(20, 2))
for i in range(10):
    ax = plt.subplot(1, 10, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %% [markdown]
# Entrainez votre auto-encodeur à débruiter les images perturbées que vous venez de générer. (x: les images bruitées, target: les images non-bruitées)

# %%
auto_encoder.fit(x_train_noisy, x_train, epochs=10, batch_size=128, shuffle=True, validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1848 - val_loss: 0.1415
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1407 - val_loss: 0.1343
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1342 - val_loss: 0.1307
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1313 - val_loss: 0.1290
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1295 - val_loss: 0.1270
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1278 - val_loss: 0.1257
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1268 - val_loss: 0.1251
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1259 - val_loss: 0.1245
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1253 - val_loss: 0.1239
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1248 - val_loss: 0.1231

# %% [markdown]
# Affichez le résultat de votre apprentissage en affichant quelques images bruitées et leur débruitage par l'auto encodeur

# %%
decoded_imgs = auto_encoder.predict(x_test_noisy)

n = 10  # Nombre d'images qu'on souhaite afficher
plt.figure(figsize=(20, 2))
for i in range(n):
    # Afficher les images originales bruitées
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title("Bruitées")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Afficher les images débruitées
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Débruitées")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.subplots_adjust(hspace=0.6)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# Les resultats sont un peu flous.
# Vous pouvez essayer d'améliorer les reconstructions en augmentant la capacité de vos réseaux, par exemple en rajoutant des filtres lors des couches de convolutions

# %%
# Encodeur
input_img = Input(shape=(28, 28, 1))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img) # Increased filters to 32
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x) # Increased filters to 64
x = MaxPooling2D((2, 2), padding='same')(x)
encoded = Conv2D(128, (3, 3), activation='relu', padding='same')(x) # Increased filters to 128

# Decodeur
x = Conv2D(128, (3, 3), activation='relu', padding='same')(encoded) # Increased filters to 128
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x) # Increased filters to 64
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Autoencodeur
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - loss: 0.1996 - val_loss: 0.1047
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1040 - val_loss: 0.0991
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0997 - val_loss: 0.0967
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0975 - val_loss: 0.0957
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0960 - val_loss: 0.0946
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0949 - val_loss: 0.0938
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0939 - val_loss: 0.0930
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0934 - val_loss: 0.0927
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0925 - val_loss: 0.0922
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0923 - val_loss: 0.0919
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0919 - val_loss: 0.0915
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0914 - val_loss: 0.0917
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0911 - val_loss: 0.0911
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0906 - val_loss: 0.0909
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0906 - val_loss: 0.0909
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0903 - val_loss: 0.0909
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0902 - val_loss: 0.0907
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.0899 - val_loss: 0.0908
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0896 - val_loss: 0.0908
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0894 - val_loss: 0.0905
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0892 - val_loss: 0.0905
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0891 - val_loss: 0.0905
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0889 - val_loss: 0.0909
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0887 - val_loss: 0.0904
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0886 - val_loss: 0.0904
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0886 - val_loss: 0.0906
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0883 - val_loss: 0.0904
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0884 - val_loss: 0.0903
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0881 - val_loss: 0.0902
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0881 - val_loss: 0.0903
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0879 - val_loss: 0.0904
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0878 - val_loss: 0.0905
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0879 - val_loss: 0.0907
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0876 - val_loss: 0.0903
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0874 - val_loss: 0.0912
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0874 - val_loss: 0.0908
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0874 - val_loss: 0.0904
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0872 - val_loss: 0.0907
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0872 - val_loss: 0.0906
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0870 - val_loss: 0.0905
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0871 - val_loss: 0.0905
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0869 - val_loss: 0.0905
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0868 - val_loss: 0.0906
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0868 - val_loss: 0.0915
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0868 - val_loss: 0.0905
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0865 - val_loss: 0.0911
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0866 - val_loss: 0.0906
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0865 - val_loss: 0.0906
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0866 - val_loss: 0.0909
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0864 - val_loss: 0.0910

# %% [markdown]
# Affichez vos nouveaux résultats:

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Afficher les images originales bruitées
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title("Bruitées")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Afficher les images débruitées
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Débruitées")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.subplots_adjust(hspace=0.6)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# **Les images débruitées sont effectivement moins floues**

# %% [markdown]
# ## U-net
# Nous allons maintenant nous concentrer sur une architecture particulière d'auto-encodeurs: les réseaux U-net.
# Les réseaux U-nets sont des auto-encodeurs ayant la particularité de posséder des connections directes entre les couches de l'encodeur et les couches du décodeur.
# ![](https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/05/Architecture-of-the-U-Net-Generator-Model.png)
# Les couches de convolutions du décodeur vont recevoir en entrées les sorties des couches qui les précèdent ainsi que les sorties des couches de convolutions correspondantes de l'encodeur.
#
# Nous allons utiliser un réseau U-net pour recoloriser des images en noir et blanc.
# Nous utiliserons le dataset [landscape](https://github.com/ml5js/ml5-data-and-models/tree/master/datasets/images/landscapes) composé de 4000 images de paysages.
# Commençons donc par télécharger le dataset.

# %%
# !wget https://github.com/ml5js/ml5-data-and-models/raw/master/datasets/images/landscapes/landscapes_small.zip
# !mkdir landscapes
# !unzip landscapes_small.zip -d landscapes
# !rm -r landscapes/__MACOSX
# Out:
# --2025-01-24 16:35:56--  https://github.com/ml5js/ml5-data-and-models/raw/master/datasets/images/landscapes/landscapes_small.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ml5js/ml5-data-and-models/master/datasets/images/landscapes/landscapes_small.zip [following]
# --2025-01-24 16:35:57--  https://raw.githubusercontent.com/ml5js/ml5-data-and-models/master/datasets/images/landscapes/landscapes_small.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81935123 (78M) [application/zip]
# Saving to: ‘landscapes_small.zip’
#
# landscapes_small.zi 100%[===================>]  78.14M   255MB/s    in 0.3s
#
# 2025-01-24 16:35:59 (255 MB/s) - ‘landscapes_small.zip’ saved [81935123/81935123]
#
# Archive:  landscapes_small.zip
#    creating: landscapes/city/
#   inflating: landscapes/city/8662091067_d68482de0a.jpg
#    creating: landscapes/__MACOSX/
#    creating: landscapes/__MACOSX/city/
#   inflating: landscapes/__MACOSX/city/._8662091067_d68482de0a.jpg
#   inflating: landscapes/city/8668164080_1ec14beefb.jpg
#   inflating: landscapes/__MACOSX/city/._8668164080_1ec14beefb.jpg
#   inflating: landscapes/city/8702483522_d65dcd8206.jpg
#   inflating: landscapes/__MACOSX/city/._8702483522_d65dcd8206.jpg
#   inflating: landscapes/city/8728135912_fdc6ff8c1b.jpg
#   inflating: landscapes/__MACOSX/city/._8728135912_fdc6ff8c1b.jpg
#   inflating: landscapes/city/8733358321_db28724b59.jpg
#   inflating: landscapes/__MACOSX/city/._8733358321_db28724b59.jpg
#   inflating: landscapes/city/8751595315_bff4c282f2.jpg
#   inflating: landscapes/__MACOSX/city/._8751595315_bff4c282f2.jpg
#   inflating: landscapes/city/8817173080_c2aa1cd2b4.jpg
#   inflating: landscapes/__MACOSX/city/._8817173080_c2aa1cd2b4.jpg
#   inflating: landscapes/city/8828837978_b5f2dd5078.jpg
#   inflating: landscapes/__MACOSX/city/._8828837978_b5f2dd5078.jpg
#   inflating: landscapes/city/9013127155_e45321d152.jpg
#   inflating: landscapes/__MACOSX/city/._9013127155_e45321d152.jpg
#   inflating: landscapes/city/9068633463_ec34ac8037.jpg
#   inflating: landscapes/__MACOSX/city/._9068633463_ec34ac8037.jpg
#   inflating: landscapes/city/9124097373_eb699e55d8.jpg
#   inflating: landscapes/__MACOSX/city/._9124097373_eb699e55d8.jpg
#   inflating: landscapes/city/9214849798_0cecc68677.jpg
#   inflating: landscapes/__MACOSX/city/._9214849798_0cecc68677.jpg
#   inflating: landscapes/city/9240056263_1d7ba64b32.jpg
#   inflating: landscapes/__MACOSX/city/._9240056263_1d7ba64b32.jpg
#   inflating: landscapes/city/9355730295_deb0c23a33.jpg
#   inflating: landscapes/__MACOSX/city/._9355730295_deb0c23a33.jpg
#   inflating: landscapes/city/9681097554_0c5ca409ff.jpg
#   inflating: landscapes/__MACOSX/city/._9681097554_0c5ca409ff.jpg
#   inflating: landscapes/city/9743736102_523e4c7792.jpg
#   inflating: landscapes/__MACOSX/city/._9743736102_523e4c7792.jpg
#   inflating: landscapes/city/9974317713_23516148f7.jpg
#   inflating: landscapes/__MACOSX/city/._9974317713_23516148f7.jpg
#   inflating: landscapes/city/9989848433_4de119dca6.jpg
#   inflating: landscapes/__MACOSX/city/._9989848433_4de119dca6.jpg
#   inflating: landscapes/city/8312511905_2e294e38f1.jpg
#   inflating: landscapes/__MACOSX/city/._8312511905_2e294e38f1.jpg
#   inflating: landscapes/city/8329281484_0b94e96a18.jpg
#   inflating: landscapes/__MACOSX/city/._8329281484_0b94e96a18.jpg
#   inflating: landscapes/city/8375042558_016ee80f64.jpg
#   inflating: landscapes/__MACOSX/city/._8375042558_016ee80f64.jpg
#   inflating: landscapes/city/8397419853_348be4190d.jpg
#   inflating: landscapes/__MACOSX/city/._8397419853_348be4190d.jpg
#   inflating: landscapes/city/8423562665_1fc3737422.jpg
#   inflating: landscapes/__MACOSX/city/._8423562665_1fc3737422.jpg
#   inflating: landscapes/city/8436248153_5dcc98d272.jpg
#   inflating: landscapes/__MACOSX/city/._8436248153_5dcc98d272.jpg
#   inflating: landscapes/city/8460385281_c4b7f20dca.jpg
#   inflating: landscapes/__MACOSX/city/._8460385281_c4b7f20dca.jpg
#   inflating: landscapes/city/8495748726_917469f95c.jpg
#   inflating: landscapes/__MACOSX/city/._8495748726_917469f95c.jpg
#   inflating: landscapes/city/8509226475_1d7ac69ce5.jpg
#   inflating: landscapes/__MACOSX/city/._8509226475_1d7ac69ce5.jpg
#   inflating: landscapes/city/8549578066_95c7e2bb49.jpg
#   inflating: landscapes/__MACOSX/city/._8549578066_95c7e2bb49.jpg
#   inflating: landscapes/city/8553010494_17448cf48b.jpg
#   inflating: landscapes/__MACOSX/city/._8553010494_17448cf48b.jpg
#   inflating: landscapes/city/8558548035_758cbb9658.jpg
#   inflating: landscapes/__MACOSX/city/._8558548035_758cbb9658.jpg
#   inflating: landscapes/city/8561007205_090aa5d751.jpg
#   inflating: landscapes/__MACOSX/city/._8561007205_090aa5d751.jpg
#   inflating: landscapes/city/8573327533_76625e1596.jpg
#   inflating: landscapes/__MACOSX/city/._8573327533_76625e1596.jpg
#   inflating: landscapes/city/8586283224_c7baa767ce.jpg
#   inflating: landscapes/__MACOSX/city/._8586283224_c7baa767ce.jpg
#   inflating: landscapes/city/5176463268_6a5ae88580.jpg
#   inflating: landscapes/__MACOSX/city/._5176463268_6a5ae88580.jpg
#   inflating: landscapes/city/5206140273_91f64e2994.jpg
#   inflating: landscapes/__MACOSX/city/._5206140273_91f64e2994.jpg
#   inflating: landscapes/city/5216680723_4dc3dba4b8.jpg
#   inflating: landscapes/__MACOSX/city/._5216680723_4dc3dba4b8.jpg
#   inflating: landscapes/city/5222698699_e536a4d7ba.jpg
#   inflating: landscapes/__MACOSX/city/._5222698699_e536a4d7ba.jpg
#   inflating: landscapes/city/5235785619_9853338d23.jpg
#   inflating: landscapes/__MACOSX/city/._5235785619_9853338d23.jpg
#   inflating: landscapes/city/5277568094_24b8a91c79.jpg
#   inflating: landscapes/__MACOSX/city/._5277568094_24b8a91c79.jpg
#   inflating: landscapes/city/5363769908_a0fa757954.jpg
#   inflating: landscapes/__MACOSX/city/._5363769908_a0fa757954.jpg
#   inflating: landscapes/city/5377892675_ba0ed753aa.jpg
#   inflating: landscapes/__MACOSX/city/._5377892675_ba0ed753aa.jpg
#   inflating: landscapes/city/5402064513_86cfd9a6d6.jpg
#   inflating: landscapes/__MACOSX/city/._5402064513_86cfd9a6d6.jpg
#   inflating: landscapes/city/5439556618_8af17997fd.jpg
#   inflating: landscapes/__MACOSX/city/._5439556618_8af17997fd.jpg
#   inflating: landscapes/city/5446847043_3eb274b7fc.jpg
#   inflating: landscapes/__MACOSX/city/._5446847043_3eb274b7fc.jpg
#   inflating: landscapes/city/5528862520_dc6fcbec45.jpg
#   inflating: landscapes/__MACOSX/city/._5528862520_dc6fcbec45.jpg
#   inflating: landscapes/city/5530750771_8f18ff014d.jpg
#   inflating: landscapes/__MACOSX/city/._5530750771_8f18ff014d.jpg
#   inflating: landscapes/city/5561122354_db00d6fa80.jpg
#   inflating: landscapes/__MACOSX/city/._5561122354_db00d6fa80.jpg
#   inflating: landscapes/city/5585723808_8a7568674f.jpg
#   inflating: landscapes/__MACOSX/city/._5585723808_8a7568674f.jpg
#   inflating: landscapes/city/5606703493_83e83ef297.jpg
#   inflating: landscapes/__MACOSX/city/._5606703493_83e83ef297.jpg
#   inflating: landscapes/city/5656157863_6c1cba44b6.jpg
#   inflating: landscapes/__MACOSX/city/._5656157863_6c1cba44b6.jpg
#   inflating: landscapes/city/5735094771_d7d6e72bfc.jpg
#   inflating: landscapes/__MACOSX/city/._5735094771_d7d6e72bfc.jpg
#   inflating: landscapes/city/5773720558_eff0dd9b02.jpg
#   inflating: landscapes/__MACOSX/city/._5773720558_eff0dd9b02.jpg
#   inflating: landscapes/city/5837892606_591f23b94e.jpg
#   inflating: landscapes/__MACOSX/city/._5837892606_591f23b94e.jpg
#   inflating: landscapes/city/5988855095_ff7bf7c121.jpg
#   inflating: landscapes/__MACOSX/city/._5988855095_ff7bf7c121.jpg
#   inflating: landscapes/city/6038442090_a111c80071.jpg
#   inflating: landscapes/__MACOSX/city/._6038442090_a111c80071.jpg
#   inflating: landscapes/city/6085590030_39aa6d1c3d.jpg
#   inflating: landscapes/__MACOSX/city/._6085590030_39aa6d1c3d.jpg
#   inflating: landscapes/city/6098453072_fb04366124.jpg
#   inflating: landscapes/__MACOSX/city/._6098453072_fb04366124.jpg
#   inflating: landscapes/city/6132499271_a0de941768.jpg
#   inflating: landscapes/__MACOSX/city/._6132499271_a0de941768.jpg
#   inflating: landscapes/city/6150478713_604956b71a.jpg
#   inflating: landscapes/__MACOSX/city/._6150478713_604956b71a.jpg
#   inflating: landscapes/city/6152855021_819e9b7337.jpg
#   inflating: landscapes/__MACOSX/city/._6152855021_819e9b7337.jpg
#   inflating: landscapes/city/6184027644_862aac354c.jpg
#   inflating: landscapes/__MACOSX/city/._6184027644_862aac354c.jpg
#   inflating: landscapes/city/6203111667_a698d00cf0.jpg
#   inflating: landscapes/__MACOSX/city/._6203111667_a698d00cf0.jpg
#   inflating: landscapes/city/6203595006_52662bf318.jpg
#   inflating: landscapes/__MACOSX/city/._6203595006_52662bf318.jpg
#   inflating: landscapes/city/6244482064_4312c1be90.jpg
#   inflating: landscapes/__MACOSX/city/._6244482064_4312c1be90.jpg
#   inflating: landscapes/city/6262320133_e1884fc737.jpg
#   inflating: landscapes/__MACOSX/city/._6262320133_e1884fc737.jpg
#   inflating: landscapes/city/6288938140_9e450c2714.jpg
#   inflating: landscapes/__MACOSX/city/._6288938140_9e450c2714.jpg
#   inflating: landscapes/city/6515679617_8585dd3bec.jpg
#   inflating: landscapes/__MACOSX/city/._6515679617_8585dd3bec.jpg
#   inflating: landscapes/city/16232892139_30d9cbfcdb.jpg
#   inflating: landscapes/__MACOSX/city/._16232892139_30d9cbfcdb.jpg
#   inflating: landscapes/city/16233203977_072a66c311.jpg
#   inflating: landscapes/__MACOSX/city/._16233203977_072a66c311.jpg
#   inflating: landscapes/city/16256024697_f283b6fa10.jpg
#   inflating: landscapes/__MACOSX/city/._16256024697_f283b6fa10.jpg
#   inflating: landscapes/city/16272792504_c9d4b77ee4.jpg
#   inflating: landscapes/__MACOSX/city/._16272792504_c9d4b77ee4.jpg
#   inflating: landscapes/city/16338396720_0ebdbe5481.jpg
#   inflating: landscapes/__MACOSX/city/._16338396720_0ebdbe5481.jpg
#   inflating: landscapes/city/16394318770_a2ce0790df.jpg
#   inflating: landscapes/__MACOSX/city/._16394318770_a2ce0790df.jpg
#   inflating: landscapes/city/16395487369_dda8f619de.jpg
#   inflating: landscapes/__MACOSX/city/._16395487369_dda8f619de.jpg
#   inflating: landscapes/city/16425198125_6849dd3c37.jpg
#   inflating: landscapes/__MACOSX/city/._16425198125_6849dd3c37.jpg
#   inflating: landscapes/city/16441930925_57c0c1de1a.jpg
#   inflating: landscapes/__MACOSX/city/._16441930925_57c0c1de1a.jpg
#   inflating: landscapes/city/16508707946_e27fb8cb4e.jpg
#   inflating: landscapes/__MACOSX/city/._16508707946_e27fb8cb4e.jpg
#   inflating: landscapes/city/16508740039_fb43f17667.jpg
#   inflating: landscapes/__MACOSX/city/._16508740039_fb43f17667.jpg
#   inflating: landscapes/city/11495090506_1304602a61.jpg
#   inflating: landscapes/__MACOSX/city/._11495090506_1304602a61.jpg
#   inflating: landscapes/city/1374567526_f63fe8f0d9.jpg
#   inflating: landscapes/__MACOSX/city/._1374567526_f63fe8f0d9.jpg
#   inflating: landscapes/city/14689762882_3bedb4a62f.jpg
#   inflating: landscapes/__MACOSX/city/._14689762882_3bedb4a62f.jpg
#   inflating: landscapes/city/15852456374_83325eaf3c.jpg
#   inflating: landscapes/__MACOSX/city/._15852456374_83325eaf3c.jpg
#   inflating: landscapes/city/16232886319_a30d876644.jpg
#   inflating: landscapes/__MACOSX/city/._16232886319_a30d876644.jpg
#   inflating: landscapes/city/16522873508_2d3e8e0f3a.jpg
#   inflating: landscapes/__MACOSX/city/._16522873508_2d3e8e0f3a.jpg
#   inflating: landscapes/city/219862655_449742dc43.jpg
#   inflating: landscapes/__MACOSX/city/._219862655_449742dc43.jpg
#   inflating: landscapes/city/24747543362_e5cd2af2dc.jpg
#   inflating: landscapes/__MACOSX/city/._24747543362_e5cd2af2dc.jpg
#   inflating: landscapes/city/26229096200_96cd74e1d3.jpg
#   inflating: landscapes/__MACOSX/city/._26229096200_96cd74e1d3.jpg
#   inflating: landscapes/city/2908583663_d5bc33c473.jpg
#   inflating: landscapes/__MACOSX/city/._2908583663_d5bc33c473.jpg
#   inflating: landscapes/city/32760281221_6d812f5c01.jpg
#   inflating: landscapes/__MACOSX/city/._32760281221_6d812f5c01.jpg
#   inflating: landscapes/city/3715538_4fc63bc071.jpg
#   inflating: landscapes/__MACOSX/city/._3715538_4fc63bc071.jpg
#   inflating: landscapes/city/39212553182_b3a36bffdd.jpg
#   inflating: landscapes/__MACOSX/city/._39212553182_b3a36bffdd.jpg
#   inflating: landscapes/city/4738587283_795aeb8443.jpg
#   inflating: landscapes/__MACOSX/city/._4738587283_795aeb8443.jpg
#   inflating: landscapes/city/5173070598_21451c6978.jpg
#   inflating: landscapes/__MACOSX/city/._5173070598_21451c6978.jpg
#   inflating: landscapes/city/5899597741_049b8459f1.jpg
#   inflating: landscapes/__MACOSX/city/._5899597741_049b8459f1.jpg
#   inflating: landscapes/city/6536097779_a0e9213ae9.jpg
#   inflating: landscapes/__MACOSX/city/._6536097779_a0e9213ae9.jpg
#   inflating: landscapes/city/7011008137_68fa978350.jpg
#   inflating: landscapes/__MACOSX/city/._7011008137_68fa978350.jpg
#   inflating: landscapes/city/8294890005_ca82657d05.jpg
#   inflating: landscapes/__MACOSX/city/._8294890005_ca82657d05.jpg
#   inflating: landscapes/city/8623354935_bb4a55bda9.jpg
#   inflating: landscapes/__MACOSX/city/._8623354935_bb4a55bda9.jpg
#   inflating: landscapes/city/32881756876_9e6c8430da.jpg
#   inflating: landscapes/__MACOSX/city/._32881756876_9e6c8430da.jpg
#   inflating: landscapes/city/32945879842_b8e36dac63.jpg
#   inflating: landscapes/__MACOSX/city/._32945879842_b8e36dac63.jpg
#   inflating: landscapes/city/3298293136_700663861a.jpg
#   inflating: landscapes/__MACOSX/city/._3298293136_700663861a.jpg
#   inflating: landscapes/city/3344242763_a241868378.jpg
#   inflating: landscapes/__MACOSX/city/._3344242763_a241868378.jpg
#   inflating: landscapes/city/33464186820_fe757a9504.jpg
#   inflating: landscapes/__MACOSX/city/._33464186820_fe757a9504.jpg
#   inflating: landscapes/city/3355357980_714ab0c8f0.jpg
#   inflating: landscapes/__MACOSX/city/._3355357980_714ab0c8f0.jpg
#   inflating: landscapes/city/338245198_77d1f95ab6.jpg
#   inflating: landscapes/__MACOSX/city/._338245198_77d1f95ab6.jpg
#   inflating: landscapes/city/33834814763_535eef67d2.jpg
#   inflating: landscapes/__MACOSX/city/._33834814763_535eef67d2.jpg
#   inflating: landscapes/city/3405806595_30426ee0dc.jpg
#   inflating: landscapes/__MACOSX/city/._3405806595_30426ee0dc.jpg
#   inflating: landscapes/city/3409468822_53ecb0d525.jpg
#   inflating: landscapes/__MACOSX/city/._3409468822_53ecb0d525.jpg
#   inflating: landscapes/city/34238596313_c13fb55efa.jpg
#   inflating: landscapes/__MACOSX/city/._34238596313_c13fb55efa.jpg
#   inflating: landscapes/city/3443839215_8b012ac247.jpg
#   inflating: landscapes/__MACOSX/city/._3443839215_8b012ac247.jpg
#   inflating: landscapes/city/35333170481_9565f6b884.jpg
#   inflating: landscapes/__MACOSX/city/._35333170481_9565f6b884.jpg
#   inflating: landscapes/city/36657130804_eeacc80e1a.jpg
#   inflating: landscapes/__MACOSX/city/._36657130804_eeacc80e1a.jpg
#   inflating: landscapes/city/3696285860_3aef0d2c9b.jpg
#   inflating: landscapes/__MACOSX/city/._3696285860_3aef0d2c9b.jpg
#   inflating: landscapes/city/37122740900_4f7151242f.jpg
#   inflating: landscapes/__MACOSX/city/._37122740900_4f7151242f.jpg
#   inflating: landscapes/city/37128768770_fb36194877.jpg
#   inflating: landscapes/__MACOSX/city/._37128768770_fb36194877.jpg
#   inflating: landscapes/city/291337873_5364377dd3.jpg
#   inflating: landscapes/__MACOSX/city/._291337873_5364377dd3.jpg
#   inflating: landscapes/city/29153802485_c12b4e3069.jpg
#   inflating: landscapes/__MACOSX/city/._29153802485_c12b4e3069.jpg
#   inflating: landscapes/city/2931395682_2b66d78182.jpg
#   inflating: landscapes/__MACOSX/city/._2931395682_2b66d78182.jpg
#   inflating: landscapes/city/2949289828_9f74bd07d7.jpg
#   inflating: landscapes/__MACOSX/city/._2949289828_9f74bd07d7.jpg
#   inflating: landscapes/city/30084705221_6001bbf1ba.jpg
#   inflating: landscapes/__MACOSX/city/._30084705221_6001bbf1ba.jpg
#   inflating: landscapes/city/304400723_3b64b0745d.jpg
#   inflating: landscapes/__MACOSX/city/._304400723_3b64b0745d.jpg
#   inflating: landscapes/city/3052982795_24bc5a7ca6.jpg
#   inflating: landscapes/__MACOSX/city/._3052982795_24bc5a7ca6.jpg
#   inflating: landscapes/city/30746321700_f00e325377.jpg
#   inflating: landscapes/__MACOSX/city/._30746321700_f00e325377.jpg
#   inflating: landscapes/city/30831771_3623f61c51.jpg
#   inflating: landscapes/__MACOSX/city/._30831771_3623f61c51.jpg
#   inflating: landscapes/city/31065520000_2a0c85a1b0.jpg
#   inflating: landscapes/__MACOSX/city/._31065520000_2a0c85a1b0.jpg
#   inflating: landscapes/city/311849259_05d14bb8db.jpg
#   inflating: landscapes/__MACOSX/city/._311849259_05d14bb8db.jpg
#   inflating: landscapes/city/3129414079_ddde7f8f04.jpg
#   inflating: landscapes/__MACOSX/city/._3129414079_ddde7f8f04.jpg
#   inflating: landscapes/city/315774020_55984b813f.jpg
#   inflating: landscapes/__MACOSX/city/._315774020_55984b813f.jpg
#   inflating: landscapes/city/3205135930_6514774c4d.jpg
#   inflating: landscapes/__MACOSX/city/._3205135930_6514774c4d.jpg
#   inflating: landscapes/city/3212771920_6ac23db25d.jpg
#   inflating: landscapes/__MACOSX/city/._3212771920_6ac23db25d.jpg
#   inflating: landscapes/city/32667744900_7032039c01.jpg
#   inflating: landscapes/__MACOSX/city/._32667744900_7032039c01.jpg
#   inflating: landscapes/city/3927830652_f34811d486.jpg
#   inflating: landscapes/__MACOSX/city/._3927830652_f34811d486.jpg
#   inflating: landscapes/city/39362406101_10bb61f3f3.jpg
#   inflating: landscapes/__MACOSX/city/._39362406101_10bb61f3f3.jpg
#   inflating: landscapes/city/39520136391_182f503d4b.jpg
#   inflating: landscapes/__MACOSX/city/._39520136391_182f503d4b.jpg
#   inflating: landscapes/city/4278776098_2ca4042698.jpg
#   inflating: landscapes/__MACOSX/city/._4278776098_2ca4042698.jpg
#   inflating: landscapes/city/4369567216_173554061f.jpg
#   inflating: landscapes/__MACOSX/city/._4369567216_173554061f.jpg
#   inflating: landscapes/city/440344421_a8cfd57327.jpg
#   inflating: landscapes/__MACOSX/city/._440344421_a8cfd57327.jpg
#   inflating: landscapes/city/4451884837_3dbbcfb260.jpg
#   inflating: landscapes/__MACOSX/city/._4451884837_3dbbcfb260.jpg
#   inflating: landscapes/city/4469359354_78f23ef964.jpg
#   inflating: landscapes/__MACOSX/city/._4469359354_78f23ef964.jpg
#   inflating: landscapes/city/4469363024_bfa557ca00.jpg
#   inflating: landscapes/__MACOSX/city/._4469363024_bfa557ca00.jpg
#   inflating: landscapes/city/4548834872_474ee1560d.jpg
#   inflating: landscapes/__MACOSX/city/._4548834872_474ee1560d.jpg
#   inflating: landscapes/city/4601580314_6e0f67e519.jpg
#   inflating: landscapes/__MACOSX/city/._4601580314_6e0f67e519.jpg
#   inflating: landscapes/city/4606056626_60b81285cb.jpg
#   inflating: landscapes/__MACOSX/city/._4606056626_60b81285cb.jpg
#   inflating: landscapes/city/4638312663_84885a480f.jpg
#   inflating: landscapes/__MACOSX/city/._4638312663_84885a480f.jpg
#   inflating: landscapes/city/4721015942_e8711135f1.jpg
#   inflating: landscapes/__MACOSX/city/._4721015942_e8711135f1.jpg
#   inflating: landscapes/city/702250212_81089595fc.jpg
#   inflating: landscapes/__MACOSX/city/._702250212_81089595fc.jpg
#   inflating: landscapes/city/7161241019_ddb9fbc362.jpg
#   inflating: landscapes/__MACOSX/city/._7161241019_ddb9fbc362.jpg
#   inflating: landscapes/city/7232388814_cc09e92688.jpg
#   inflating: landscapes/__MACOSX/city/._7232388814_cc09e92688.jpg
#   inflating: landscapes/city/7406288976_70b3fe4df9.jpg
#   inflating: landscapes/__MACOSX/city/._7406288976_70b3fe4df9.jpg
#   inflating: landscapes/city/7460426516_33570c13ea.jpg
#   inflating: landscapes/__MACOSX/city/._7460426516_33570c13ea.jpg
#   inflating: landscapes/city/7478239096_ef3d8abcc1.jpg
#   inflating: landscapes/__MACOSX/city/._7478239096_ef3d8abcc1.jpg
#   inflating: landscapes/city/7516223700_d70b7952e7.jpg
#   inflating: landscapes/__MACOSX/city/._7516223700_d70b7952e7.jpg
#   inflating: landscapes/city/7553959762_2f71bf9c4a.jpg
#   inflating: landscapes/__MACOSX/city/._7553959762_2f71bf9c4a.jpg
#   inflating: landscapes/city/7677782252_57fa206485.jpg
#   inflating: landscapes/__MACOSX/city/._7677782252_57fa206485.jpg
#   inflating: landscapes/city/775133154_83457c8e1e.jpg
#   inflating: landscapes/__MACOSX/city/._775133154_83457c8e1e.jpg
#   inflating: landscapes/city/7834738162_252d9458fa.jpg
#   inflating: landscapes/__MACOSX/city/._7834738162_252d9458fa.jpg
#   inflating: landscapes/city/7856914842_16e136c331.jpg
#   inflating: landscapes/__MACOSX/city/._7856914842_16e136c331.jpg
#   inflating: landscapes/city/7956070652_0bdaf044b3.jpg
#   inflating: landscapes/__MACOSX/city/._7956070652_0bdaf044b3.jpg
#   inflating: landscapes/city/8012285085_b8f71ab934.jpg
#   inflating: landscapes/__MACOSX/city/._8012285085_b8f71ab934.jpg
#   inflating: landscapes/city/8012937586_5e71769fb9.jpg
#   inflating: landscapes/__MACOSX/city/._8012937586_5e71769fb9.jpg
#   inflating: landscapes/city/8015774285_21d86d6a22.jpg
#   inflating: landscapes/__MACOSX/city/._8015774285_21d86d6a22.jpg
#   inflating: landscapes/city/8050848586_759ea0d553.jpg
#   inflating: landscapes/__MACOSX/city/._8050848586_759ea0d553.jpg
#   inflating: landscapes/city/8158295598_3802c12ecf.jpg
#   inflating: landscapes/__MACOSX/city/._8158295598_3802c12ecf.jpg
#   inflating: landscapes/city/8179796178_bc2d9b3898.jpg
#   inflating: landscapes/__MACOSX/city/._8179796178_bc2d9b3898.jpg
#   inflating: landscapes/city/8216963492_47f14bcf3f.jpg
#   inflating: landscapes/__MACOSX/city/._8216963492_47f14bcf3f.jpg
#   inflating: landscapes/city/8245363540_47b9493548.jpg
#   inflating: landscapes/__MACOSX/city/._8245363540_47b9493548.jpg
#   inflating: landscapes/city/8245633859_48d8dcd569.jpg
#   inflating: landscapes/__MACOSX/city/._8245633859_48d8dcd569.jpg
#   inflating: landscapes/city/8256153940_412a382127.jpg
#   inflating: landscapes/__MACOSX/city/._8256153940_412a382127.jpg
#   inflating: landscapes/city/8256592323_4a851212b9.jpg
#   inflating: landscapes/__MACOSX/city/._8256592323_4a851212b9.jpg
#   inflating: landscapes/city/8264124766_5d59389f26.jpg
#   inflating: landscapes/__MACOSX/city/._8264124766_5d59389f26.jpg
#   inflating: landscapes/city/8270763427_70a17737ed.jpg
#   inflating: landscapes/__MACOSX/city/._8270763427_70a17737ed.jpg
#   inflating: landscapes/city/8276587554_f2fb9284d9.jpg
#   inflating: landscapes/__MACOSX/city/._8276587554_f2fb9284d9.jpg
#   inflating: landscapes/city/8293712287_1e2b1a9baf.jpg
#   inflating: landscapes/__MACOSX/city/._8293712287_1e2b1a9baf.jpg
#   inflating: landscapes/city/11563563864_de37f61e80.jpg
#   inflating: landscapes/__MACOSX/city/._11563563864_de37f61e80.jpg
#   inflating: landscapes/city/11624560624_600b918603.jpg
#   inflating: landscapes/__MACOSX/city/._11624560624_600b918603.jpg
#   inflating: landscapes/city/1164542102_1679dec0a1.jpg
#   inflating: landscapes/__MACOSX/city/._1164542102_1679dec0a1.jpg
#   inflating: landscapes/city/11719685136_eb1560a52d.jpg
#   inflating: landscapes/__MACOSX/city/._11719685136_eb1560a52d.jpg
#   inflating: landscapes/city/11783164766_78b4169933.jpg
#   inflating: landscapes/__MACOSX/city/._11783164766_78b4169933.jpg
#   inflating: landscapes/city/11856127576_a459776232.jpg
#   inflating: landscapes/__MACOSX/city/._11856127576_a459776232.jpg
#   inflating: landscapes/city/11921587636_3c2beed532.jpg
#   inflating: landscapes/__MACOSX/city/._11921587636_3c2beed532.jpg
#   inflating: landscapes/city/12297352426_5849a9e5e3.jpg
#   inflating: landscapes/__MACOSX/city/._12297352426_5849a9e5e3.jpg
#   inflating: landscapes/city/12341406463_c422a312d2.jpg
#   inflating: landscapes/__MACOSX/city/._12341406463_c422a312d2.jpg
#   inflating: landscapes/city/12433480454_2185bcd18b.jpg
#   inflating: landscapes/__MACOSX/city/._12433480454_2185bcd18b.jpg
#   inflating: landscapes/city/12576664853_5940022170.jpg
#   inflating: landscapes/__MACOSX/city/._12576664853_5940022170.jpg
#   inflating: landscapes/city/12611287235_dd2d0a403e.jpg
#   inflating: landscapes/__MACOSX/city/._12611287235_dd2d0a403e.jpg
#   inflating: landscapes/city/12731216975_5608a77970.jpg
#   inflating: landscapes/__MACOSX/city/._12731216975_5608a77970.jpg
#   inflating: landscapes/city/12771071373_ab18b35114.jpg
#   inflating: landscapes/__MACOSX/city/._12771071373_ab18b35114.jpg
#   inflating: landscapes/city/14797765609_3f11e4bbfd.jpg
#   inflating: landscapes/__MACOSX/city/._14797765609_3f11e4bbfd.jpg
#   inflating: landscapes/city/14825378330_660becff3c.jpg
#   inflating: landscapes/__MACOSX/city/._14825378330_660becff3c.jpg
#   inflating: landscapes/city/14833184498_83a6d12b56.jpg
#   inflating: landscapes/__MACOSX/city/._14833184498_83a6d12b56.jpg
#   inflating: landscapes/city/14896930262_a158618e01.jpg
#   inflating: landscapes/__MACOSX/city/._14896930262_a158618e01.jpg
#   inflating: landscapes/city/15034475073_11ee0935e7.jpg
#   inflating: landscapes/__MACOSX/city/._15034475073_11ee0935e7.jpg
#   inflating: landscapes/city/15093389936_589ee7ebd6.jpg
#   inflating: landscapes/__MACOSX/city/._15093389936_589ee7ebd6.jpg
#   inflating: landscapes/city/15124736409_b54a67526b.jpg
#   inflating: landscapes/__MACOSX/city/._15124736409_b54a67526b.jpg
#   inflating: landscapes/city/15259550703_00ed4da52c.jpg
#   inflating: landscapes/__MACOSX/city/._15259550703_00ed4da52c.jpg
#   inflating: landscapes/city/15407893046_8aa3e124a6.jpg
#   inflating: landscapes/__MACOSX/city/._15407893046_8aa3e124a6.jpg
#   inflating: landscapes/city/15411264498_be7b412058.jpg
#   inflating: landscapes/__MACOSX/city/._15411264498_be7b412058.jpg
#   inflating: landscapes/city/15482980162_3e57308530.jpg
#   inflating: landscapes/__MACOSX/city/._15482980162_3e57308530.jpg
#   inflating: landscapes/city/15822160983_3dd97be356.jpg
#   inflating: landscapes/__MACOSX/city/._15822160983_3dd97be356.jpg
#   inflating: landscapes/city/15842058412_cccae0abd8.jpg
#   inflating: landscapes/__MACOSX/city/._15842058412_cccae0abd8.jpg
#   inflating: landscapes/city/24748847885_69666d6d90.jpg
#   inflating: landscapes/__MACOSX/city/._24748847885_69666d6d90.jpg
#   inflating: landscapes/city/25014803458_2b50f3f7bd.jpg
#   inflating: landscapes/__MACOSX/city/._25014803458_2b50f3f7bd.jpg
#   inflating: landscapes/city/25098711280_09533bc99e.jpg
#   inflating: landscapes/__MACOSX/city/._25098711280_09533bc99e.jpg
#   inflating: landscapes/city/25150693072_83f5336430.jpg
#   inflating: landscapes/__MACOSX/city/._25150693072_83f5336430.jpg
#   inflating: landscapes/city/2517906298_1efe0d1e86.jpg
#   inflating: landscapes/__MACOSX/city/._2517906298_1efe0d1e86.jpg
#   inflating: landscapes/city/25294868280_c75ec4fd66.jpg
#   inflating: landscapes/__MACOSX/city/._25294868280_c75ec4fd66.jpg
#   inflating: landscapes/city/25713187828_d010ba3ba0.jpg
#   inflating: landscapes/__MACOSX/city/._25713187828_d010ba3ba0.jpg
#   inflating: landscapes/city/25762701024_e8cc4c4df5.jpg
#   inflating: landscapes/__MACOSX/city/._25762701024_e8cc4c4df5.jpg
#   inflating: landscapes/city/2576460320_2a975bfe1e.jpg
#   inflating: landscapes/__MACOSX/city/._2576460320_2a975bfe1e.jpg
#   inflating: landscapes/city/25817552616_910a2d3412.jpg
#   inflating: landscapes/__MACOSX/city/._25817552616_910a2d3412.jpg
#   inflating: landscapes/city/2594030953_6f4bbf8938.jpg
#   inflating: landscapes/__MACOSX/city/._2594030953_6f4bbf8938.jpg
#   inflating: landscapes/city/26041694101_f336598673.jpg
#   inflating: landscapes/__MACOSX/city/._26041694101_f336598673.jpg
#   inflating: landscapes/city/26589688844_eb6b608f9e.jpg
#   inflating: landscapes/__MACOSX/city/._26589688844_eb6b608f9e.jpg
#   inflating: landscapes/city/2663169607_9d756bdd7f.jpg
#   inflating: landscapes/__MACOSX/city/._2663169607_9d756bdd7f.jpg
#   inflating: landscapes/city/26656266535_decb35dc87.jpg
#   inflating: landscapes/__MACOSX/city/._26656266535_decb35dc87.jpg
#   inflating: landscapes/city/26885591862_9f4b29ea9c.jpg
#   inflating: landscapes/__MACOSX/city/._26885591862_9f4b29ea9c.jpg
#   inflating: landscapes/city/27223190063_a5f494d957.jpg
#   inflating: landscapes/__MACOSX/city/._27223190063_a5f494d957.jpg
#   inflating: landscapes/city/2744027382_c61e69e115.jpg
#   inflating: landscapes/__MACOSX/city/._2744027382_c61e69e115.jpg
#   inflating: landscapes/city/27557015840_a495d71c04.jpg
#   inflating: landscapes/__MACOSX/city/._27557015840_a495d71c04.jpg
#   inflating: landscapes/city/27574463359_f730eebf71.jpg
#   inflating: landscapes/__MACOSX/city/._27574463359_f730eebf71.jpg
#   inflating: landscapes/city/27733715252_ee28d4bf91.jpg
#   inflating: landscapes/__MACOSX/city/._27733715252_ee28d4bf91.jpg
#   inflating: landscapes/city/27800889586_5dc9b6943f.jpg
#   inflating: landscapes/__MACOSX/city/._27800889586_5dc9b6943f.jpg
#   inflating: landscapes/city/27823415839_a6ef78f42e.jpg
#   inflating: landscapes/__MACOSX/city/._27823415839_a6ef78f42e.jpg
#   inflating: landscapes/city/27835017165_ba45d36116.jpg
#   inflating: landscapes/__MACOSX/city/._27835017165_ba45d36116.jpg
#   inflating: landscapes/city/27868456972_69ef095c0b.jpg
#   inflating: landscapes/__MACOSX/city/._27868456972_69ef095c0b.jpg
#   inflating: landscapes/city/28750907625_2352b6697b.jpg
#   inflating: landscapes/__MACOSX/city/._28750907625_2352b6697b.jpg
#   inflating: landscapes/city/4834733408_97aebf1d67.jpg
#   inflating: landscapes/__MACOSX/city/._4834733408_97aebf1d67.jpg
#   inflating: landscapes/city/4890320546_d9a57d63e3.jpg
#   inflating: landscapes/__MACOSX/city/._4890320546_d9a57d63e3.jpg
#   inflating: landscapes/city/4896090130_d1df7b62d2.jpg
#   inflating: landscapes/__MACOSX/city/._4896090130_d1df7b62d2.jpg
#   inflating: landscapes/city/4905639853_37a883f49b.jpg
#   inflating: landscapes/__MACOSX/city/._4905639853_37a883f49b.jpg
#   inflating: landscapes/city/496697501_d189de223d.jpg
#   inflating: landscapes/__MACOSX/city/._496697501_d189de223d.jpg
#   inflating: landscapes/city/497828328_b54bc7c10d.jpg
#   inflating: landscapes/__MACOSX/city/._497828328_b54bc7c10d.jpg
#   inflating: landscapes/city/4999182652_ced34028ee.jpg
#   inflating: landscapes/__MACOSX/city/._4999182652_ced34028ee.jpg
#   inflating: landscapes/city/5016399019_970102963c.jpg
#   inflating: landscapes/__MACOSX/city/._5016399019_970102963c.jpg
#   inflating: landscapes/city/5017004014_94e7e8482d.jpg
#   inflating: landscapes/__MACOSX/city/._5017004014_94e7e8482d.jpg
#   inflating: landscapes/city/5080425171_a2cebd42b7.jpg
#   inflating: landscapes/__MACOSX/city/._5080425171_a2cebd42b7.jpg
#   inflating: landscapes/city/5148028163_02939ab39c.jpg
#   inflating: landscapes/__MACOSX/city/._5148028163_02939ab39c.jpg
#   inflating: landscapes/city/5153221366_a8d2db189d.jpg
#   inflating: landscapes/__MACOSX/city/._5153221366_a8d2db189d.jpg
#   inflating: landscapes/city/5156392117_09885cb288.jpg
#   inflating: landscapes/__MACOSX/city/._5156392117_09885cb288.jpg
#   inflating: landscapes/city/5172522550_14326567ee.jpg
#   inflating: landscapes/__MACOSX/city/._5172522550_14326567ee.jpg
#   inflating: landscapes/city/10010664593_8d5cfe0d9f.jpg
#   inflating: landscapes/__MACOSX/city/._10010664593_8d5cfe0d9f.jpg
#   inflating: landscapes/city/10022214816_089b237f7c.jpg
#   inflating: landscapes/__MACOSX/city/._10022214816_089b237f7c.jpg
#   inflating: landscapes/city/10044951014_ca0e00a0ba.jpg
#   inflating: landscapes/__MACOSX/city/._10044951014_ca0e00a0ba.jpg
#   inflating: landscapes/city/10146018305_aca5dac226.jpg
#   inflating: landscapes/__MACOSX/city/._10146018305_aca5dac226.jpg
#   inflating: landscapes/city/10256229503_183c6004eb.jpg
#   inflating: landscapes/__MACOSX/city/._10256229503_183c6004eb.jpg
#   inflating: landscapes/city/10443931784_b5a13317b6.jpg
#   inflating: landscapes/__MACOSX/city/._10443931784_b5a13317b6.jpg
#   inflating: landscapes/city/10483050734_de56979e52.jpg
#   inflating: landscapes/__MACOSX/city/._10483050734_de56979e52.jpg
#   inflating: landscapes/city/1050371876_aa030b8bf8.jpg
#   inflating: landscapes/__MACOSX/city/._1050371876_aa030b8bf8.jpg
#   inflating: landscapes/city/10617559395_dd1b43ed97.jpg
#   inflating: landscapes/__MACOSX/city/._10617559395_dd1b43ed97.jpg
#   inflating: landscapes/city/10753433375_1ce41cfdab.jpg
#   inflating: landscapes/__MACOSX/city/._10753433375_1ce41cfdab.jpg
#   inflating: landscapes/city/10760928685_fc01f4be4e.jpg
#   inflating: landscapes/__MACOSX/city/._10760928685_fc01f4be4e.jpg
#   inflating: landscapes/city/10811696816_9b8f9597a2.jpg
#   inflating: landscapes/__MACOSX/city/._10811696816_9b8f9597a2.jpg
#   inflating: landscapes/city/1120451078_730807e18c.jpg
#   inflating: landscapes/__MACOSX/city/._1120451078_730807e18c.jpg
#   inflating: landscapes/city/11245271645_be148183cc.jpg
#   inflating: landscapes/__MACOSX/city/._11245271645_be148183cc.jpg
#   inflating: landscapes/city/11285730373_2b07a176ec.jpg
#   inflating: landscapes/__MACOSX/city/._11285730373_2b07a176ec.jpg
#   inflating: landscapes/city/11371096356_0088ba7fdb.jpg
#   inflating: landscapes/__MACOSX/city/._11371096356_0088ba7fdb.jpg
#   inflating: landscapes/city/16527072900_38409a71fa.jpg
#   inflating: landscapes/__MACOSX/city/._16527072900_38409a71fa.jpg
#   inflating: landscapes/city/16540442223_1fd8d50c96.jpg
#   inflating: landscapes/__MACOSX/city/._16540442223_1fd8d50c96.jpg
#   inflating: landscapes/city/16636621602_05d0e77996.jpg
#   inflating: landscapes/__MACOSX/city/._16636621602_05d0e77996.jpg
#   inflating: landscapes/city/16726668132_ea17d421ff.jpg
#   inflating: landscapes/__MACOSX/city/._16726668132_ea17d421ff.jpg
#   inflating: landscapes/city/16748409027_263c961e9b.jpg
#   inflating: landscapes/__MACOSX/city/._16748409027_263c961e9b.jpg
#   inflating: landscapes/city/16778782291_e35fe6a3ef.jpg
#   inflating: landscapes/__MACOSX/city/._16778782291_e35fe6a3ef.jpg
#   inflating: landscapes/city/16821272931_fcb62b3a9d.jpg
#   inflating: landscapes/__MACOSX/city/._16821272931_fcb62b3a9d.jpg
#   inflating: landscapes/city/16954095570_e597e10530.jpg
#   inflating: landscapes/__MACOSX/city/._16954095570_e597e10530.jpg
#   inflating: landscapes/city/17185539767_13425614e6.jpg
#   inflating: landscapes/__MACOSX/city/._17185539767_13425614e6.jpg
#   inflating: landscapes/city/18122720155_c65ce00d67.jpg
#   inflating: landscapes/__MACOSX/city/._18122720155_c65ce00d67.jpg
#   inflating: landscapes/city/1938347972_002298d78c.jpg
#   inflating: landscapes/__MACOSX/city/._1938347972_002298d78c.jpg
#   inflating: landscapes/city/1986757176_c282cb3613.jpg
#   inflating: landscapes/__MACOSX/city/._1986757176_c282cb3613.jpg
#   inflating: landscapes/city/2050402831_a9db92b3fb.jpg
#   inflating: landscapes/__MACOSX/city/._2050402831_a9db92b3fb.jpg
#   inflating: landscapes/city/6641541547_fc2b8f6d5d.jpg
#   inflating: landscapes/__MACOSX/city/._6641541547_fc2b8f6d5d.jpg
#   inflating: landscapes/city/6662245419_29b608da9c.jpg
#   inflating: landscapes/__MACOSX/city/._6662245419_29b608da9c.jpg
#   inflating: landscapes/city/6687463953_065f859d57.jpg
#   inflating: landscapes/__MACOSX/city/._6687463953_065f859d57.jpg
#   inflating: landscapes/city/6735789163_809f177bb5.jpg
#   inflating: landscapes/__MACOSX/city/._6735789163_809f177bb5.jpg
#   inflating: landscapes/city/675942960_c016eb8402.jpg
#   inflating: landscapes/__MACOSX/city/._675942960_c016eb8402.jpg
#   inflating: landscapes/city/6792874377_689985a832.jpg
#   inflating: landscapes/__MACOSX/city/._6792874377_689985a832.jpg
#   inflating: landscapes/city/6798691689_9aba49b9f2.jpg
#   inflating: landscapes/__MACOSX/city/._6798691689_9aba49b9f2.jpg
#   inflating: landscapes/city/6798694739_1a0abb7d3c.jpg
#   inflating: landscapes/__MACOSX/city/._6798694739_1a0abb7d3c.jpg
#   inflating: landscapes/city/6798701043_2f5e28b0ed.jpg
#   inflating: landscapes/__MACOSX/city/._6798701043_2f5e28b0ed.jpg
#   inflating: landscapes/city/6875276295_98d1da992c.jpg
#   inflating: landscapes/__MACOSX/city/._6875276295_98d1da992c.jpg
#   inflating: landscapes/city/6884355293_f6912cb59c.jpg
#   inflating: landscapes/__MACOSX/city/._6884355293_f6912cb59c.jpg
#   inflating: landscapes/city/6887277110_dbc5be5fc5.jpg
#   inflating: landscapes/__MACOSX/city/._6887277110_dbc5be5fc5.jpg
#   inflating: landscapes/city/6900718338_b7ca36e810.jpg
#   inflating: landscapes/__MACOSX/city/._6900718338_b7ca36e810.jpg
#   inflating: landscapes/city/6930630954_95d53339d0.jpg
#   inflating: landscapes/__MACOSX/city/._6930630954_95d53339d0.jpg
#   inflating: landscapes/city/13920027738_d1cb705289.jpg
#   inflating: landscapes/__MACOSX/city/._13920027738_d1cb705289.jpg
#   inflating: landscapes/city/13920041608_63b5866604.jpg
#   inflating: landscapes/__MACOSX/city/._13920041608_63b5866604.jpg
#   inflating: landscapes/city/13920053088_0a3e0a9153.jpg
#   inflating: landscapes/__MACOSX/city/._13920053088_0a3e0a9153.jpg
#   inflating: landscapes/city/1406449370_55e4dca92b.jpg
#   inflating: landscapes/__MACOSX/city/._1406449370_55e4dca92b.jpg
#   inflating: landscapes/city/14188039276_b19c60fc10.jpg
#   inflating: landscapes/__MACOSX/city/._14188039276_b19c60fc10.jpg
#   inflating: landscapes/city/14212064145_6feb3920f7.jpg
#   inflating: landscapes/__MACOSX/city/._14212064145_6feb3920f7.jpg
#   inflating: landscapes/city/1423280792_4b10c3b7e7.jpg
#   inflating: landscapes/__MACOSX/city/._1423280792_4b10c3b7e7.jpg
#   inflating: landscapes/city/1423635798_c670255428.jpg
#   inflating: landscapes/__MACOSX/city/._1423635798_c670255428.jpg
#   inflating: landscapes/city/14253649007_e98d7a6169.jpg
#   inflating: landscapes/__MACOSX/city/._14253649007_e98d7a6169.jpg
#   inflating: landscapes/city/14338100010_1e44f4e9eb.jpg
#   inflating: landscapes/__MACOSX/city/._14338100010_1e44f4e9eb.jpg
#   inflating: landscapes/city/14353967752_44b0a4e1b7.jpg
#   inflating: landscapes/__MACOSX/city/._14353967752_44b0a4e1b7.jpg
#   inflating: landscapes/city/14363124329_3083908953.jpg
#   inflating: landscapes/__MACOSX/city/._14363124329_3083908953.jpg
#   inflating: landscapes/city/14448574213_e5a60e8dac.jpg
#   inflating: landscapes/__MACOSX/city/._14448574213_e5a60e8dac.jpg
#   inflating: landscapes/city/14501644346_5a8ec30d1b.jpg
#   inflating: landscapes/__MACOSX/city/._14501644346_5a8ec30d1b.jpg
#   inflating: landscapes/city/14582751142_2e7d6b072c.jpg
#   inflating: landscapes/__MACOSX/city/._14582751142_2e7d6b072c.jpg
#   inflating: landscapes/city/14587675739_ffd221e608.jpg
#   inflating: landscapes/__MACOSX/city/._14587675739_ffd221e608.jpg
#   inflating: landscapes/city/14629076445_ffcff33b98.jpg
#   inflating: landscapes/__MACOSX/city/._14629076445_ffcff33b98.jpg
#   inflating: landscapes/city/22150955192_e12e78eeeb.jpg
#   inflating: landscapes/__MACOSX/city/._22150955192_e12e78eeeb.jpg
#   inflating: landscapes/city/2295734732_bba4a06136.jpg
#   inflating: landscapes/__MACOSX/city/._2295734732_bba4a06136.jpg
#   inflating: landscapes/city/2301255658_c28b0ddcdb.jpg
#   inflating: landscapes/__MACOSX/city/._2301255658_c28b0ddcdb.jpg
#   inflating: landscapes/city/2310926674_75f5695c8e.jpg
#   inflating: landscapes/__MACOSX/city/._2310926674_75f5695c8e.jpg
#   inflating: landscapes/city/23127637212_de7c80339c.jpg
#   inflating: landscapes/__MACOSX/city/._23127637212_de7c80339c.jpg
#   inflating: landscapes/city/2318427740_965d618bc2.jpg
#   inflating: landscapes/__MACOSX/city/._2318427740_965d618bc2.jpg
#   inflating: landscapes/city/23315580174_4fb3fcbaf3.jpg
#   inflating: landscapes/__MACOSX/city/._23315580174_4fb3fcbaf3.jpg
#   inflating: landscapes/city/23497065018_a64b038898.jpg
#   inflating: landscapes/__MACOSX/city/._23497065018_a64b038898.jpg
#   inflating: landscapes/city/2380625494_8c62e72e11.jpg
#   inflating: landscapes/__MACOSX/city/._2380625494_8c62e72e11.jpg
#   inflating: landscapes/city/239248438_96fceedfba.jpg
#   inflating: landscapes/__MACOSX/city/._239248438_96fceedfba.jpg
#   inflating: landscapes/city/23939454188_cd1ba3fde2.jpg
#   inflating: landscapes/__MACOSX/city/._23939454188_cd1ba3fde2.jpg
#   inflating: landscapes/city/24221683488_8ea7fbbd56.jpg
#   inflating: landscapes/__MACOSX/city/._24221683488_8ea7fbbd56.jpg
#   inflating: landscapes/city/2445907735_210dae2d0a.jpg
#   inflating: landscapes/__MACOSX/city/._2445907735_210dae2d0a.jpg
#   inflating: landscapes/city/24722493176_3efb183c21.jpg
#   inflating: landscapes/__MACOSX/city/._24722493176_3efb183c21.jpg
#   inflating: landscapes/city/15870138710_8a5be4accb.jpg
#   inflating: landscapes/__MACOSX/city/._15870138710_8a5be4accb.jpg
#   inflating: landscapes/city/15950913534_4fcb5f95b4.jpg
#   inflating: landscapes/__MACOSX/city/._15950913534_4fcb5f95b4.jpg
#   inflating: landscapes/city/15962752882_6062c93895.jpg
#   inflating: landscapes/__MACOSX/city/._15962752882_6062c93895.jpg
#   inflating: landscapes/city/15995682791_deac57990b.jpg
#   inflating: landscapes/__MACOSX/city/._15995682791_deac57990b.jpg
#   inflating: landscapes/city/16025988242_ba06d5318c.jpg
#   inflating: landscapes/__MACOSX/city/._16025988242_ba06d5318c.jpg
#   inflating: landscapes/city/16026677705_67b9e36eed.jpg
#   inflating: landscapes/__MACOSX/city/._16026677705_67b9e36eed.jpg
#   inflating: landscapes/city/16026717185_5563e099b1.jpg
#   inflating: landscapes/__MACOSX/city/._16026717185_5563e099b1.jpg
#   inflating: landscapes/city/16058311104_c33d981334.jpg
#   inflating: landscapes/__MACOSX/city/._16058311104_c33d981334.jpg
#   inflating: landscapes/city/16092204416_703e81eef9.jpg
#   inflating: landscapes/__MACOSX/city/._16092204416_703e81eef9.jpg
#   inflating: landscapes/city/37243653956_630dc4b448.jpg
#   inflating: landscapes/__MACOSX/city/._37243653956_630dc4b448.jpg
#   inflating: landscapes/city/37408003041_1826a2a8a9.jpg
#   inflating: landscapes/__MACOSX/city/._37408003041_1826a2a8a9.jpg
#   inflating: landscapes/city/37430711876_ba2aff0d46.jpg
#   inflating: landscapes/__MACOSX/city/._37430711876_ba2aff0d46.jpg
#   inflating: landscapes/city/37697599605_1d6b6335be.jpg
#   inflating: landscapes/__MACOSX/city/._37697599605_1d6b6335be.jpg
#   inflating: landscapes/city/37785486192_b9bf498005.jpg
#   inflating: landscapes/__MACOSX/city/._37785486192_b9bf498005.jpg
#   inflating: landscapes/city/37837277781_a0438f6284.jpg
#   inflating: landscapes/__MACOSX/city/._37837277781_a0438f6284.jpg
#   inflating: landscapes/city/38110054635_96e04cc1e0.jpg
#   inflating: landscapes/__MACOSX/city/._38110054635_96e04cc1e0.jpg
#   inflating: landscapes/city/384541923_f5b2a9ef5d.jpg
#   inflating: landscapes/__MACOSX/city/._384541923_f5b2a9ef5d.jpg
#   inflating: landscapes/city/38659041426_854f34600c.jpg
#   inflating: landscapes/__MACOSX/city/._38659041426_854f34600c.jpg
#   inflating: landscapes/city/38692900415_f3bb4cae9f.jpg
#   inflating: landscapes/__MACOSX/city/._38692900415_f3bb4cae9f.jpg
#    creating: landscapes/field/
#   inflating: landscapes/field/9109673051_475c501897.jpg
#   inflating: landscapes/field/9167191364_f3871b2ba6.jpg
#   inflating: landscapes/field/9196588449_e10e0e4466.jpg
#   inflating: landscapes/field/9202429296_7a4589c5f8.jpg
#   inflating: landscapes/field/9299945751_b4e0dc8991.jpg
#   inflating: landscapes/field/9302731986_0ca59b6fa5.jpg
#   inflating: landscapes/field/9314681173_b45c4e81df.jpg
#   inflating: landscapes/field/9317474822_df3e03be30.jpg
#   inflating: landscapes/field/9354127034_2c687c4117.jpg
#   inflating: landscapes/field/9396850214_d84b1669c3.jpg
#   inflating: landscapes/field/9485890233_4982c5078f.jpg
#   inflating: landscapes/field/9486433807_3633d505f7.jpg
#   inflating: landscapes/field/9509637116_9cc564d0c6.jpg
#   inflating: landscapes/field/952834502_e61e5ff7df.jpg
#   inflating: landscapes/field/9531829424_a15d731fd1.jpg
#   inflating: landscapes/field/9560611832_8cd6ce479f.jpg
#   inflating: landscapes/field/9663859620_6677c9cb00.jpg
#   inflating: landscapes/field/9721656297_03f8a177d5.jpg
#   inflating: landscapes/field/974598319_f5c9e577ee.jpg
#   inflating: landscapes/field/9945593643_bf523b0e31.jpg
#   inflating: landscapes/field/995162041_8ff523a958.jpg
#   inflating: landscapes/field/7886633344_8cf620fb70.jpg
#   inflating: landscapes/field/7903153288_719f2852d6.jpg
#   inflating: landscapes/field/795088310_d860a4f2fd.jpg
#   inflating: landscapes/field/8072680027_325c51aac1.jpg
#   inflating: landscapes/field/8106435227_19db149c48.jpg
#   inflating: landscapes/field/8112621482_f645862e1b.jpg
#   inflating: landscapes/field/8135058710_0f698412ca.jpg
#   inflating: landscapes/field/820007318_d4abdb3a7d.jpg
#   inflating: landscapes/field/8321064765_035f81b16e.jpg
#   inflating: landscapes/field/8333835755_680cf88841.jpg
#   inflating: landscapes/field/83932897_9475d74aae.jpg
#   inflating: landscapes/field/83932934_984620b112.jpg
#   inflating: landscapes/field/83932959_9d421f52a8.jpg
#   inflating: landscapes/field/83949784_200448f65b.jpg
#   inflating: landscapes/field/83950143_e55af7d772.jpg
#   inflating: landscapes/field/843507962_085511b0e0.jpg
#   inflating: landscapes/field/85475908_a3f40b5304.jpg
#   inflating: landscapes/field/8630719706_be05a0c80f.jpg
#   inflating: landscapes/field/8645158855_57bf736c98.jpg
#   inflating: landscapes/field/8729372942_892ddb82e8.jpg
#   inflating: landscapes/field/8748090150_f3020d8a62.jpg
#   inflating: landscapes/field/8748820_49c3892bab.jpg
#   inflating: landscapes/field/87687835_d232248d3a.jpg
#   inflating: landscapes/field/8883092521_071c314fc6.jpg
#   inflating: landscapes/field/891124998_9bcb4164ea.jpg
#   inflating: landscapes/field/9049177423_6f6b67f967.jpg
#   inflating: landscapes/field/9053196068_6d96d01a0f.jpg
#   inflating: landscapes/field/2699152186_ba98829c65.jpg
#   inflating: landscapes/field/27037550001_3eba453b0c.jpg
#   inflating: landscapes/field/27073494556_03295fe29b.jpg
#   inflating: landscapes/field/27094664364_17ba735bd8.jpg
#   inflating: landscapes/field/27355754_3e0cc63b3a.jpg
#   inflating: landscapes/field/27356020_bf1489bfa0.jpg
#   inflating: landscapes/field/27404148081_522a826f41.jpg
#   inflating: landscapes/field/27488278102_7a8c0a4f7c.jpg
#   inflating: landscapes/field/2751059899_72c5a165fe.jpg
#   inflating: landscapes/field/27573517651_e43643cbce.jpg
#   inflating: landscapes/field/27587932433_5646466194.jpg
#   inflating: landscapes/field/2769768179_0822c8154a.jpg
#   inflating: landscapes/field/2783281103_98d3896840.jpg
#   inflating: landscapes/field/2787003280_e5a5a1caa2.jpg
#   inflating: landscapes/field/27881172241_af1fa724bb.jpg
#   inflating: landscapes/field/3935898026_080c2ec897.jpg
#   inflating: landscapes/field/3955448143_0fbee2950e.jpg
#   inflating: landscapes/field/3976706701_440629b10a.jpg
#   inflating: landscapes/field/3993143072_bc7782daf8.jpg
#   inflating: landscapes/field/400359314_71fb81ac3d.jpg
#   inflating: landscapes/field/4031098971_0d0698f15f.jpg
#   inflating: landscapes/field/4043129858_92fa568537.jpg
#   inflating: landscapes/field/4054822135_7f7e2a650f.jpg
#   inflating: landscapes/field/4072668122_a92d505030.jpg
#   inflating: landscapes/field/4080562789_a68ea97fa1.jpg
#   inflating: landscapes/field/415565164_48f69b7ee8.jpg
#   inflating: landscapes/field/415804061_bf2915acf6.jpg
#   inflating: landscapes/field/4188952423_b3da0f1837.jpg
#   inflating: landscapes/field/4192130036_e2debb2ec5.jpg
#   inflating: landscapes/field/4285347909_670b636183.jpg
#   inflating: landscapes/field/4287723542_083684c902.jpg
#   inflating: landscapes/field/4301141416_1f2a2df3f8.jpg
#   inflating: landscapes/field/4325566415_1dd4676fef.jpg
#   inflating: landscapes/field/4362726749_1d6ddaba8d.jpg
#   inflating: landscapes/field/4422442595_c8e63a89bc.jpg
#   inflating: landscapes/field/4451793373_70cf0def21.jpg
# ...
#   inflating: landscapes/road/5549079282_3662327f2c.jpg
#   inflating: landscapes/road/5563650869_25bc3fa9ca.jpg
#   inflating: landscapes/road/5564040792_22ab96337e.jpg
#   inflating: landscapes/road/5581400244_49e7b6a786.jpg
#   inflating: landscapes/road/5603013970_53d0e77105.jpg
#   inflating: landscapes/road/5608736811_60b3a47d69.jpg
#   inflating: landscapes/road/5611925447_5f17cfe37d.jpg
#   inflating: landscapes/road/5633661323_dd9efdbcdb.jpg
#   inflating: landscapes/road/5640259279_9769cf64ac.jpg
#   inflating: landscapes/road/5642129553_757e24dd1c.jpg
#   inflating: landscapes/road/565917444_b71d9ac6e0.jpg
#   inflating: landscapes/road/5671389224_4afeea2d37.jpg
#   inflating: landscapes/road/5674546721_a2e61e2ff0.jpg
#   inflating: landscapes/road/5699070073_e05aa22f63.jpg
#   inflating: landscapes/road/5761722584_b06343cd9e.jpg
#   inflating: landscapes/road/5774210842_e5d3e9c48a.jpg
#   inflating: landscapes/road/4194656388_8bed664ede.jpg
#   inflating: landscapes/road/4211119216_3210b6e4fa.jpg
#   inflating: landscapes/road/4219542063_2effd09c53.jpg
#   inflating: landscapes/road/4249231099_c3e8d8c023.jpg
#   inflating: landscapes/road/4284086900_118e870ff5.jpg
#   inflating: landscapes/road/429441942_3867451336.jpg
#   inflating: landscapes/road/4297131888_b8731c4388.jpg
#   inflating: landscapes/road/430091108_7ac48ef565.jpg
#   inflating: landscapes/road/4322627270_8bf52f11be.jpg
#   inflating: landscapes/road/4325574175_1b39366b14.jpg
#   inflating: landscapes/road/4326229034_9a13e49081.jpg
#   inflating: landscapes/road/4337977311_21d25be467.jpg
#   inflating: landscapes/road/4343850998_564ac11feb.jpg
#   inflating: landscapes/road/4349399716_342b29c525.jpg
#   inflating: landscapes/road/444706391_7805e148fd.jpg
#   inflating: landscapes/road/446056253_86b0de48b1.jpg
#   inflating: landscapes/road/4466899725_2c62b92a48.jpg
#   inflating: landscapes/road/4476216989_f6906f5211.jpg
#   inflating: landscapes/road/4485275968_6ea3295275.jpg
#   inflating: landscapes/road/4494780303_220c62dbf8.jpg
#   inflating: landscapes/road/4516071581_189d422399.jpg
#   inflating: landscapes/road/4521641544_cd1d2f09d3.jpg
#   inflating: landscapes/road/4529769735_5677871cdb.jpg
#   inflating: landscapes/road/4529769975_61e5a9429d.jpg
#   inflating: landscapes/road/4585765969_eb9f165c29.jpg
#   inflating: landscapes/road/4586403240_3d09d02866.jpg
#   inflating: landscapes/road/4588505927_2034b5ae44.jpg
#   inflating: landscapes/road/4640515544_95998aae54.jpg
#   inflating: landscapes/road/14815108133_17063ec73b.jpg
#   inflating: landscapes/road/148157718_6b954bb46d.jpg
#   inflating: landscapes/road/1490223303_18f23f73fc.jpg
#   inflating: landscapes/road/14909238446_dafce69d03.jpg
#   inflating: landscapes/road/14924162224_d921289f25.jpg
#   inflating: landscapes/road/14933047815_ce418719b3.jpg
#   inflating: landscapes/road/15005851023_e982932865.jpg
#   inflating: landscapes/road/15022074206_e008f3b5aa.jpg
#   inflating: landscapes/road/15052458077_7c02797819.jpg
#   inflating: landscapes/road/15056727931_bc42e6a038.jpg
#   inflating: landscapes/road/15073913475_e47df72baf.jpg
#   inflating: landscapes/road/15170219403_6628fa4b26.jpg
#   inflating: landscapes/road/15210531753_966457613c.jpg
#   inflating: landscapes/road/15214051925_83b6a550ee.jpg
#   inflating: landscapes/road/15218960264_0e7ce7a0c5.jpg
#   inflating: landscapes/road/15221973924_fb246e73a1.jpg
#   inflating: landscapes/road/152290479_6c0e40df5c.jpg
#   inflating: landscapes/road/15234386535_2d5d1d144a.jpg
#   inflating: landscapes/road/15251887719_599f61d708.jpg
#   inflating: landscapes/road/15277076021_e6e8e55aae.jpg
#   inflating: landscapes/road/15285104072_0493ee0eda.jpg
#   inflating: landscapes/road/152876404_1dddcbad72.jpg
#   inflating: landscapes/road/15332868644_708cf4ab08.jpg
#   inflating: landscapes/road/15340433068_605055f852.jpg
#   inflating: landscapes/road/1534510566_e827ecfc85.jpg
#   inflating: landscapes/road/15354353922_054dae48bb.jpg
#   inflating: landscapes/road/15424772976_2755a4c062.jpg
#   inflating: landscapes/road/15489704260_85f37e1cd2.jpg
#   inflating: landscapes/road/15520552215_9a27fc30fe.jpg
#   inflating: landscapes/road/127728089_6eb7631a43.jpg
#   inflating: landscapes/road/12825284825_9105e55273.jpg
#   inflating: landscapes/road/128485006_437cd3f3c1.jpg
#   inflating: landscapes/road/13010927615_99620dd65d.jpg
#   inflating: landscapes/road/13174777425_09f4e49b5d.jpg
#   inflating: landscapes/road/13395361344_e324b601f1.jpg
#   inflating: landscapes/road/1345472332_8411f148ed.jpg
#   inflating: landscapes/road/1351359878_7acebf7181.jpg
#   inflating: landscapes/road/13519602875_880925a13e.jpg
#   inflating: landscapes/road/1356022069_6b445c5382.jpg
#   inflating: landscapes/road/136578267_59eea38170.jpg
#   inflating: landscapes/road/13826582463_6be7d1f34f.jpg
#   inflating: landscapes/road/13889699248_38f6a4daa0.jpg
#   inflating: landscapes/road/13899061864_e78112bf4c.jpg
#   inflating: landscapes/road/139432484_ddd5d3d4c7.jpg
#   inflating: landscapes/road/5793006542_4a89c7abda.jpg
#   inflating: landscapes/road/5886219359_c8beb75325.jpg
#   inflating: landscapes/road/5916503171_db386df195.jpg
#   inflating: landscapes/road/5916503343_52efedaeb0.jpg
#   inflating: landscapes/road/5929981038_ddaa46ee88.jpg
#   inflating: landscapes/road/5941104541_abb8972266.jpg
#   inflating: landscapes/road/5941104667_8de55c1379.jpg
#   inflating: landscapes/road/5941105083_0539aa1d21.jpg
#   inflating: landscapes/road/5941105345_e5d38a53ca.jpg
#   inflating: landscapes/road/5941105595_08d5e760fe.jpg
#   inflating: landscapes/road/5941107051_8b8b3d2e49.jpg
#   inflating: landscapes/road/5941664154_cb73bd1510.jpg
#   inflating: landscapes/road/5941664552_4883837563.jpg
#   inflating: landscapes/road/5941664698_ee9024d12c.jpg
#   inflating: landscapes/road/6932414882_95f2b3fbfa.jpg
#   inflating: landscapes/road/6950205383_0c54b6dd62.jpg
#   inflating: landscapes/road/6962718658_0d9778bb2d.jpg
#   inflating: landscapes/road/698714521_1e046d4eae.jpg
#   inflating: landscapes/road/7032938913_109fed5473.jpg
#   inflating: landscapes/road/7129778705_9a6c02e0bb.jpg
#   inflating: landscapes/road/713028190_13d697a632.jpg
#   inflating: landscapes/road/7169898588_b0e778e9cf.jpg
#   inflating: landscapes/road/7280834104_fd4b6489b1.jpg
#   inflating: landscapes/road/7330173612_d2d7e5e951.jpg
#   inflating: landscapes/road/740431177_640b1e0409.jpg
#   inflating: landscapes/road/7504089480_e6dc43cb78.jpg
#   inflating: landscapes/road/75335811_cd782919b5.jpg
#   inflating: landscapes/road/7615171758_b0683546ba.jpg
#   inflating: landscapes/road/7782300216_b6616569e9.jpg
#   inflating: landscapes/road/7844166886_ef7de1c18e.jpg
#   inflating: landscapes/road/7847240542_0b6085765c.jpg
#   inflating: landscapes/road/7866597492_c69e5c61e0.jpg
#   inflating: landscapes/road/7866655840_43cfca608c.jpg
#   inflating: landscapes/road/7866698878_a6c3eff9f0.jpg
#   inflating: landscapes/road/7901828994_60c95f9858.jpg
#   inflating: landscapes/road/7948746474_6df37efe3b.jpg
#   inflating: landscapes/road/7948747090_bd6c6b7236.jpg
#   inflating: landscapes/road/79907918_e8dc0fe6a3.jpg
#   inflating: landscapes/road/7996987424_da4d3d01f1.jpg
#   inflating: landscapes/road/8008651812_dbc8bc2da5.jpg
#   inflating: landscapes/road/8059963385_a38f1e2fce.jpg
#   inflating: landscapes/road/8060343901_ab56c050b8.jpg
#   inflating: landscapes/road/81052187_27ecc09223.jpg
#   inflating: landscapes/road/8110042550_4b6703d371.jpg
#   inflating: landscapes/road/8113279273_f519b137af.jpg
#   inflating: landscapes/road/8117562134_66df94604b.jpg
#   inflating: landscapes/road/3639759722_15cf6c80c1.jpg
#   inflating: landscapes/road/3651705328_fcb704f276.jpg
#   inflating: landscapes/road/3659827406_44f0fccfaa.jpg
#   inflating: landscapes/road/3677296594_59af8b8f2e.jpg
#   inflating: landscapes/road/3691362307_9e648d3539.jpg
#   inflating: landscapes/road/36963097643_c0afd42e5d.jpg
#   inflating: landscapes/road/36990830176_e97e651883.jpg
#   inflating: landscapes/road/37077484440_4ee6b0a3df.jpg
#   inflating: landscapes/road/37209740682_324b1fba19.jpg
#   inflating: landscapes/road/37236197252_3750ec7099.jpg
#   inflating: landscapes/road/3726737170_9e5a019f46.jpg
#   inflating: landscapes/road/37321199111_389fc0d62e.jpg
#   inflating: landscapes/road/37418190651_e0bce51c02.jpg
#   inflating: landscapes/road/37447011446_3572742cbe.jpg
#   inflating: landscapes/road/37456339406_2293099028.jpg
#   inflating: landscapes/road/22815694142_82ef8a8847.jpg
#   inflating: landscapes/road/23123868249_525442385b.jpg
#   inflating: landscapes/road/23454923791_fbf83d4562.jpg
#   inflating: landscapes/road/235638185_f3ad7db168.jpg
#   inflating: landscapes/road/2359730110_3ae280eb96.jpg
#   inflating: landscapes/road/2361724751_55b49b98b4.jpg
#   inflating: landscapes/road/23638645864_9f450b30f1.jpg
#   inflating: landscapes/road/2369102800_dc4239dda4.jpg
#   inflating: landscapes/road/23719517903_7b540da994.jpg
#   inflating: landscapes/road/2378634716_54f57800dd.jpg
#   inflating: landscapes/road/23907747768_050bf10db5.jpg
#   inflating: landscapes/road/23977178388_0e0b575705.jpg
#   inflating: landscapes/road/23989088147_eb1c43e063.jpg
#   inflating: landscapes/road/2427779576_0d3e5d3eac.jpg
#   inflating: landscapes/road/24286754273_8f1808c0a0.jpg
#   inflating: landscapes/road/2445775387_6fd4aa7cb0.jpg
#   inflating: landscapes/road/247652288_a38df96b9e.jpg
#   inflating: landscapes/road/2483661331_fd2b8b10c4.jpg
#   inflating: landscapes/road/2483663169_9dba079e37.jpg
#   inflating: landscapes/road/25185541358_2b0b3f4c5f.jpg
#   inflating: landscapes/road/2532638841_f85b7cc5aa.jpg
#   inflating: landscapes/road/25387052433_a5d779f5cc.jpg
#   inflating: landscapes/road/2544464654_0bd07275dc.jpg
#   inflating: landscapes/road/25475423886_9a749f0b74.jpg
#   inflating: landscapes/road/2547976384_349a69d274.jpg
#   inflating: landscapes/road/25680708_399379647e.jpg
#   inflating: landscapes/road/25746761368_787c4b0451.jpg
#   inflating: landscapes/road/25854719343_6252dc411c.jpg
#   inflating: landscapes/road/25989892606_226fd11fb4.jpg
#   inflating: landscapes/road/260994771_03464241b2.jpg
#   inflating: landscapes/road/2611998145_9bfe8aa637.jpg
#   inflating: landscapes/road/2852232536_6cbb8820e1.jpg
#   inflating: landscapes/road/2857814154_8305acb723.jpg
#   inflating: landscapes/road/28580421370_460a663e9d.jpg
#   inflating: landscapes/road/2864061755_98f103b9b7.jpg
#   inflating: landscapes/road/286797134_33ab0f4bf8.jpg
#   inflating: landscapes/road/2868073936_07b95bd3a0.jpg
#   inflating: landscapes/road/2891147973_308eeb832b.jpg
#   inflating: landscapes/road/290896489_686d6d08a1.jpg
#   inflating: landscapes/road/2911930733_d3fe3849fb.jpg
#   inflating: landscapes/road/2923968663_5ca893a282.jpg
#   inflating: landscapes/road/294109686_82e7eabd36.jpg
#   inflating: landscapes/road/29456212105_2781ec19ce.jpg
#   inflating: landscapes/road/2954093767_22553a5503.jpg
#   inflating: landscapes/road/2962152686_3a6def007b.jpg
#   inflating: landscapes/road/3992194525_5e37479514.jpg
#   inflating: landscapes/road/4056361921_6249b22c58.jpg
#   inflating: landscapes/road/40852663_54b7813743.jpg
#   inflating: landscapes/road/4105641341_bb0e787a06.jpg
#   inflating: landscapes/road/4106411944_25e962cb30.jpg
#   inflating: landscapes/road/4108388751_d75f1410b3.jpg
#   inflating: landscapes/road/4109154278_b21c919f1d.jpg
#   inflating: landscapes/road/4126362982_3627446149.jpg
#   inflating: landscapes/road/4136318497_90140efd7f.jpg
#   inflating: landscapes/road/4139325320_a9136017da.jpg
#   inflating: landscapes/road/4140297647_2f2a91c3f4.jpg
#   inflating: landscapes/road/4144314716_8207e31880.jpg
#   inflating: landscapes/road/4178241983_ea32eb931a.jpg
#   inflating: landscapes/road/4190629239_c3dac0d3df.jpg
#   inflating: landscapes/road/4190906399_0f17d79924.jpg
#   inflating: landscapes/road/3015189691_a610600f7e.jpg
#   inflating: landscapes/road/3073582549_66b3492800.jpg
#   inflating: landscapes/road/3084675589_cd23eb2b31.jpg
#   inflating: landscapes/road/3084678419_98234be3db.jpg
#   inflating: landscapes/road/3084708015_63d4ace434.jpg
#   inflating: landscapes/road/3084873694_1ed2c7d2fc.jpg
#   inflating: landscapes/road/3085515490_fcafdc7c74.jpg
#   inflating: landscapes/road/3085543942_1cd80f60f4.jpg
#   inflating: landscapes/road/3133732926_67d179d22a.jpg
#   inflating: landscapes/road/3148239033_4fca293ae8.jpg
#   inflating: landscapes/road/3148297673_84c5882954.jpg
#   inflating: landscapes/road/3149059332_08a447bef9.jpg
#   inflating: landscapes/road/31687486811_b489b0fc20.jpg
#   inflating: landscapes/road/3240191793_83c526ffaf.jpg
#   inflating: landscapes/road/5287864795_4791060f89.jpg
#   inflating: landscapes/road/5296669892_233ac4c374.jpg
#   inflating: landscapes/road/5299926410_5a2cba6386.jpg
#   inflating: landscapes/road/5300890273_0a9f4a31c9.jpg
#   inflating: landscapes/road/5323777183_763fb2df9f.jpg
#   inflating: landscapes/road/5330695070_547275389d.jpg
#   inflating: landscapes/road/5375787497_063e5872f1.jpg
#   inflating: landscapes/road/5386026891_cd058eac63.jpg
#   inflating: landscapes/road/5386629778_c2f1b49282.jpg
#   inflating: landscapes/road/5388917012_167255bf95.jpg
#   inflating: landscapes/road/5388917208_47c939ce08.jpg
#   inflating: landscapes/road/5389073497_3ef339c20f.jpg
#   inflating: landscapes/road/5394370811_acdd80437d.jpg
#   inflating: landscapes/road/5395070404_ebb98bfb65.jpg
#   inflating: landscapes/road/12728044363_513cd696cf.jpg
#   inflating: landscapes/road/1394497360_ae6b261bed.jpg
#   inflating: landscapes/road/14776979873_b49cf1f377.jpg
#   inflating: landscapes/road/15535711396_a3bebbf1de.jpg
#   inflating: landscapes/road/1907611554_a872970d3c.jpg
#   inflating: landscapes/road/2262226241_c1cd472d45.jpg
#   inflating: landscapes/road/2446100453_ed99106dc6.jpg
#   inflating: landscapes/road/261725629_b4608918aa.jpg
#   inflating: landscapes/road/2832004246_da4b5ff3c8.jpg
#   inflating: landscapes/road/2994421437_e9f337b4d5.jpg
#   inflating: landscapes/road/32569437701_b5ddebe586.jpg
#   inflating: landscapes/road/3485772845_3cd1a2cb64.jpg
#   inflating: landscapes/road/3628055472_74ce3926a3.jpg
#   inflating: landscapes/road/3758117836_781801c781.jpg
#   inflating: landscapes/road/3957894091_6c74067d04.jpg
#   inflating: landscapes/road/3760958711_3deafa76fb.jpg
#   inflating: landscapes/road/37633805671_f4d4da5e59.jpg
#   inflating: landscapes/road/37959898054_a2eca39015.jpg
#   inflating: landscapes/road/38091223442_f0ea016b34.jpg
#   inflating: landscapes/road/38175740945_a53888a967.jpg
#   inflating: landscapes/road/38298107775_20d4e295aa.jpg
#   inflating: landscapes/road/3830896296_005e93e117.jpg
#   inflating: landscapes/road/3840818029_3a0d39dbe1.jpg
#   inflating: landscapes/road/3841058961_8a8619275f.jpg
#   inflating: landscapes/road/3841791403_ca9f929310.jpg
#   inflating: landscapes/road/3843342537_7c5e92430c.jpg
#   inflating: landscapes/road/3843351139_74eaf514d6.jpg
#   inflating: landscapes/road/3883174942_c3143f2ab2.jpg
#   inflating: landscapes/road/3953799778_28af6796bc.jpg
#   inflating: landscapes/road/19100401594_fb7f18049b.jpg
#   inflating: landscapes/road/19727658521_bc9158f80c.jpg
#   inflating: landscapes/road/19729913941_60dd302a18.jpg
#   inflating: landscapes/road/204143040_cbec7a36a5.jpg
#   inflating: landscapes/road/20646876991_ee052c6129.jpg
#   inflating: landscapes/road/2070836920_b444c0a76e.jpg
#   inflating: landscapes/road/2098109195_c6a6eb22bc.jpg
#   inflating: landscapes/road/2109541178_36081c7c8b.jpg
#   inflating: landscapes/road/2179090019_b00b25c515.jpg
#   inflating: landscapes/road/21831792486_c36fb5cbea.jpg
#   inflating: landscapes/road/21958625652_061a268269.jpg
#   inflating: landscapes/road/2208591182_70e9b794c5.jpg
#   inflating: landscapes/road/2222010475_c83494bdfa.jpg
#   inflating: landscapes/road/2242242617_ea37cd3790.jpg

# %% [markdown]
# Le dataset est uniquement constitué d'images en couleurs.
# Nous allons nous même générer les images en noir et blanc à l'aide de l'option ```color_mode``` des ```
# ImageDataGenerator```.
# Nous allons utiliser ici 4 générateurs: deux fournissant des images en couleurs et deux des images en noir et blanc.
# Les générateurs utiliseront la même seed afin que les images en noir et blanc et en couleurs se correspondent.

# %%
# !pip install tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Import from tensorflow.keras instead of keras directly

input_dir = 'landscapes'

seed = 1

color_datagen = ImageDataGenerator(rescale=1/255.0, validation_split=0.1)
bw_datagen = ImageDataGenerator(rescale=1/255.0, validation_split=0.1)


train_color_generator = color_datagen.flow_from_directory(input_dir, class_mode=None, seed=seed, subset='training', target_size=(256, 256))
train_bw_generator = bw_datagen.flow_from_directory(input_dir, color_mode='grayscale', class_mode=None, seed=seed, subset='training', target_size=(256, 256))
valid_color_generator = color_datagen.flow_from_directory(input_dir, class_mode=None, seed=seed, subset='validation', target_size=(256, 256))
valid_bw_generator = bw_datagen.flow_from_directory(input_dir, color_mode='grayscale', class_mode=None, seed=seed, subset='validation', target_size=(256, 256))

train_generator = (pair for pair in zip(train_bw_generator, train_color_generator))
validation_generator = (pair for pair in zip(valid_bw_generator, valid_color_generator))
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Found 3405 images belonging to 7 classes.
# Found 3405 images belonging to 7 classes.
# Found 376 images belonging to 7 classes.
# Found 376 images belonging to 7 classes.

# %% [markdown]
# Regardons un exemple du de la sortie de nos générateurs

# %%
x, y = next(train_generator)
print(x.shape, y.shape)
print(x.min(), x.max(), y.min(), y.max())

fig, (ax1, ax2) = plt.subplots(1, 2)
idx = np.random.randint(0, len(x))
ax1.imshow(np.squeeze(x[idx], axis=-1), cmap='gray')
ax2.imshow(y[idx])
# Out:
# (32, 256, 256, 1) (32, 256, 256, 3)
# 0.0 1.0 0.0 1.0

# %% [markdown]
# L'un des avantages de la construction fonctionnelle en Keras est de permettre la definition de fonctions composées facilement réutilisables.
# En voici un exemple: la fonction suivante permet de combiner une couche de convolution suivie d'une batchnormalisation en un seul appel:

# %%
from tensorflow.keras.layers import BatchNormalization

def downsampling(input, filters):
    d = Conv2D(filters, kernel_size=4, strides=2, padding='same', activation='relu')(input)
    d = BatchNormalization()(d)
    return d

# %% [markdown]
# Codez une fonction ```upsampling(input, skip_input, filters)``` qui reçoit deux entrées:
# * Une de sa couche précédente
# * Une de la couche de la couche de l'encodeur correspondante
#
#
# La fonction doit alors:
# * Faire un UpSampling de ```input``` suivit d'une Convolution avec fonction d'activation ReLU puis d'une Batch Normalisation.
# Utilisez un ```kernel_size=4``` un ```strides=1``` et ```padding='same'``` lors de la convolution afin que la sortie soit de la même taille que ```skip_input```
# * [Concatener](https://keras.io/layers/merge/) la sortie de la Batch Normalisation avec ```skip_input```  (exemple: ```a = Concatenate()([a, b])```

# %%
from tensorflow.keras.layers import UpSampling2D, Conv2D, BatchNormalization, Concatenate

def upsampling(layer_input, skip_input, filters):
    u = UpSampling2D(size=2)(layer_input)  # Upsample by factor of 2
    u = Conv2D(filters, kernel_size=4, strides=1, padding='same', activation='relu')(u) # Apply convolution
    u = BatchNormalization()(u) # Apply batch normalization
    u = Concatenate()([u, skip_input]) # Concatenate with skip input
    return u

# %% [markdown]
# Vous allez maintenant définir votre réseau U-net en vous appuyant sur le shéma suivant:
# ![](https://drive.google.com/uc?id=1F1uuhhRnXhV53aR1chU41Z17krRt2cuU)

# %%
# Image input
d0 = Input(shape=(256, 256, 1)) # Input shape based on your generator output

# Downsampling
d1 = downsampling(d0, 64)
d2 = downsampling(d1, 128)
d3 = downsampling(d2, 256)
d4 = downsampling(d3, 512)
d5 = downsampling(d4, 512)
d6 = downsampling(d5, 512)
d7 = downsampling(d6, 512)

# Upsampling
u1 = upsampling(d7, d6, 512)
u2 = upsampling(u1, d5, 512)
u3 = upsampling(u2, d4, 512)
u4 = upsampling(u3, d3, 256)
u5 = upsampling(u4, d2, 128)
u6 = upsampling(u5, d1, 64)
# Last upsampling
u7 = UpSampling2D(size=2)(u6)
u7 = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='sigmoid')(u7)

model = Model(d0, u7)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
model.fit(train_generator, steps_per_epoch=100, epochs=10, validation_data=validation_generator, validation_steps=10)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - loss: 0.0242 - mae: 0.1022 - mse: 0.0242 - val_loss: 0.2139 - val_mae: 0.3830 - val_mse: 0.2139
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - loss: 0.0082 - mae: 0.0625 - mse: 0.0082 - val_loss: 0.0870 - val_mae: 0.2343 - val_mse: 0.0870
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0087 - mae: 0.0643 - mse: 0.0087 - val_loss: 0.0497 - val_mae: 0.1816 - val_mse: 0.0497
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0076 - mae: 0.0600 - mse: 0.0076 - val_loss: 0.0509 - val_mae: 0.1700 - val_mse: 0.0509
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0079 - mae: 0.0610 - mse: 0.0079 - val_loss: 0.0204 - val_mae: 0.1171 - val_mse: 0.0204
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0076 - mae: 0.0592 - mse: 0.0076 - val_loss: 0.0127 - val_mae: 0.0901 - val_mse: 0.0127
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0076 - mae: 0.0598 - mse: 0.0076 - val_loss: 0.0089 - val_mae: 0.0684 - val_mse: 0.0089
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0070 - mae: 0.0572 - mse: 0.0070 - val_loss: 0.0093 - val_mae: 0.0704 - val_mse: 0.0093
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0071 - mae: 0.0581 - mse: 0.0071 - val_loss: 0.0958 - val_mae: 0.2272 - val_mse: 0.0958
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.0068 - mae: 0.0567 - mse: 0.0068 - val_loss: 0.0100 - val_mae: 0.0674 - val_mse: 0.0100

# %% [markdown]
# Affichez maintenant plusieurs exemples du résultat de votre apprentissage:
#
#
# *   Image en noir et blanc
# *   Image en couleur d'origine
# *   Image recolorisée par le réseau

# %%
# Prendre un batch de données de validation
x_batch, y_batch = next(validation_generator)

n = 5

plt.figure(figsize=(20, 4))

for i in range(n):
    # Afficher les images grises
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(np.squeeze(x_batch[i]), cmap='gray')  # Remove extra dimension for display
    plt.title("Grayscale")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Afficher les images colorées originales
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(y_batch[i])
    plt.title("Original")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Afficher les images colorées
    prediction = model.predict(x_batch[i:i+1])[0] # Predict on a single image
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(prediction)
    plt.title("Colorized")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.subplots_adjust(hspace=0.5)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %% [markdown]
# Pour aller plus loin avec les auto-encodeurs:
# * Un article bien détaillé sur une amélioration des auto-encodeurs permettant de générer des nouveaux exemples: [les variationals auto-encoders](http://louistiao.me/posts/implementing-variational-autoencoders-in-keras-beyond-the-quickstart-tutorial/):
# * Il y a quelques années un challenge Kaggle portait sur le débruitage de documents manuscrits: https://www.kaggle.com/c/denoising-dirty-documents/overview. Vous pouvez essayer d'utiliser des auto-encodeurs pour débruiter le dataset
